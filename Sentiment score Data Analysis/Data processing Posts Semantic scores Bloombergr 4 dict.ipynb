# %%
import csv
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
import pandas_datareader.data as web
import statsmodels.api as sm
from statsmodels.tsa.stattools import grangercausalitytests
from matplotlib import pyplot
import scipy.stats
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.ar_model import AR
# %matplotlib inline

# %%
fpath = 'facebook_data_bloombergmarkets_post_sentiment_4dict.tsv'
post_data = pd.read_csv(fpath, sep='\t')
post_data.head()
# Out:
#    ID            PostID             PostDate  \
# 0   1  3847873015280995  2021-05-16 00:03:09
# 1   2  3846792925389004  2021-05-15 16:09:27
# 2   3  3846326078769022  2021-05-15 12:34:37
# 3   4  3845819882152975  2021-05-15 08:30:13
# 4   5  3845620125506284  2021-05-15 06:41:53
#
#                                                 Text  Likes  Shares  \
# 0  BREAKING: Billionaire George Soros’s investmen...      0       0
# 1  LATEST: America’s millions of unused doses are...      0       0
# 2  Singapore's tourism industry is racing to catc...      0       0
# 3  Asian stocks are falling further behind their ...      0       0
# 4  Taiwan, seen as a model for tackling Covid, ti...      0       0
#
#    WNPositive  WNNegative  WNNeutral  WNSentiment  ...  HVTokenQnt  \
# 0       0.250       0.625     16.125       -0.375  ...          24
# 1       0.125       1.250      8.625       -1.125  ...          19
# 2       0.375       0.000     12.625        0.375  ...          16
# 3       0.375       1.500     10.125       -1.125  ...           9
# 4       0.500       0.250     15.250        0.250  ...          19
#
#    HVSentiAvg  LMPositive  LMNegative  LMTokenQnt  LMSentiAvg  Vader_Positive  \
# 0    0.041667           0           2          24   -0.083333           0.047
# 1    0.052632           1           1          19    0.000000           0.105
# 2    0.000000           0           0          16    0.000000           0.000
# 3   -0.444444           0           1           9   -0.111111           0.000
# 4   -0.052632           0           2          19   -0.105263           0.000
#
#    Vader_Negative  Vader_Neutral  Vader_Compound
# 0           0.108          0.846         -0.4404
# 1           0.093          0.802          0.0772
# 2           0.000          1.000          0.0000
# 3           0.222          0.778         -0.6908
# 4           0.000          1.000          0.0000
#
# [5 rows x 24 columns]

# %%
post_data['Vader_Average'] = post_data['Vader_Positive'] - post_data['Vader_Negative']

# %%
bins = np.linspace(-1, 1, 100)
pyplot.hist(post_data['WNSentiAvg'], bins, alpha=0.5, label='WNSentiAvg')
pyplot.hist(post_data['HVSentiAvg'], bins, alpha=0.5, label='HVSentiAvg')
pyplot.hist(post_data['LMSentiAvg'], bins, alpha=0.5, label='LMSentiAvg')
pyplot.hist(post_data['Vader_Compound'], bins, alpha=0.5, label='Vader_Compound')
pyplot.hist(post_data['Vader_Positive'] - post_data['Vader_Negative'], bins, alpha=0.5, label='Vader_Average')
pyplot.legend(loc='upper right')
pyplot.title('Distribution of semantic scores')
pyplot.show()

# %%
# seaborn histogram
sns.distplot((post_data['Vader_Compound'] - post_data['Vader_Compound'].mean())/post_data['Vader_Compound'].std(), hist=False, kde=True, 
             bins=int(180/5), color = 'red',
             hist_kws={'edgecolor':'black'})
sns.distplot((post_data['WNSentiAvg'] - post_data['WNSentiAvg'].mean())/post_data['WNSentiAvg'].std(), hist=False, kde=True, 
             bins=int(180/5), color = 'blue',
             hist_kws={'edgecolor':'black'})
sns.distplot((post_data['LMSentiAvg'] - post_data['LMSentiAvg'].mean())/post_data['LMSentiAvg'].std(), hist=False, kde=True, 
             bins=int(180/5), color = 'green',
             hist_kws={'edgecolor':'black'})
sns.distplot((post_data['HVSentiAvg'] - post_data['HVSentiAvg'].mean())/post_data['HVSentiAvg'].std(), hist=False, kde=True, 
             bins=int(180/5), color = 'orange',
             hist_kws={'edgecolor':'black'})
sns.distplot((post_data['Vader_Average'] - post_data['Vader_Average'].mean())/post_data['Vader_Average'].std(), hist=False, kde=True, 
             bins=int(180/5), color = 'purple',
             hist_kws={'edgecolor':'black'})
# Add labels
plt.title('Distribution of Sentiment Score')
plt.xlabel('Score')
plt.ylabel('Posts')
# Out:
# Text(0, 0.5, 'Posts')

# %%
post_data[['WNSentiAvg','HVSentiAvg','LMSentiAvg','Vader_Compound','Vader_Average']].describe()
# Out:
#          WNSentiAvg    HVSentiAvg    LMSentiAvg  Vader_Compound  Vader_Average
# count  12274.000000  12274.000000  12274.000000    12274.000000   12274.000000
# mean       0.004533     -0.005829     -0.035970       -0.013559      -0.006331
# std        0.061284      0.149381      0.087688        0.435768       0.157698
# min       -0.541667     -0.714286     -0.571429       -0.975300      -0.624000
# 25%       -0.020833     -0.100000     -0.083333       -0.340000      -0.107000
# 50%        0.000000      0.000000      0.000000        0.000000       0.000000
# 75%        0.035714      0.090909      0.000000        0.318200       0.093000
# max        0.410714      1.000000      1.000000        0.984200       0.652000

# %%
post_data['PostDate'] = pd.to_datetime(post_data['PostDate'], errors='coerce')

post_data['DateMonth'] = post_data['PostDate'].dt.strftime('%Y-%m')
post_data['DateDay'] = post_data['PostDate'].dt.strftime('%Y-%m-%d')

# %%
post_data['DateMonth'].head()
# Out:
# 0    2021-05
# 1    2021-05
# 2    2021-05
# 3    2021-05
# 4    2021-05
# Name: DateMonth, dtype: object

# %%
post_data.columns
# Out:
# Index(['ID', 'PostID', 'PostDate', 'Text', 'Likes', 'Shares', 'WNPositive',
#        'WNNegative', 'WNNeutral', 'WNSentiment', 'WNTokenQnt', 'WNSentiAvg',
#        'HVPositive', 'HVNegative', 'HVTokenQnt', 'HVSentiAvg', 'LMPositive',
#        'LMNegative', 'LMTokenQnt', 'LMSentiAvg', 'Vader_Positive',
#        'Vader_Negative', 'Vader_Neutral', 'Vader_Compound', 'Vader_Average',
#        'DateMonth', 'DateDay'],
#       dtype='object')

# %%
Monthly_Data = post_data.groupby('DateMonth').agg({'WNSentiAvg': 'sum'
                                                         ,'WNTokenQnt':'count'
                                                        ,'Vader_Compound':'mean'
                                                        ,'Vader_Average': 'mean'
                                                        ,'HVPositive':'sum'
                                                        ,'HVNegative':'sum'
                                                        ,'HVTokenQnt':'sum'
                                                        ,'LMPositive':'sum'
                                                        ,'LMNegative':'sum'
                                                        ,'LMTokenQnt':'sum'
                                                       })

# %%
DailyData = post_data.groupby('DateDay').agg({'WNSentiAvg': 'sum'
                                                        ,'WNTokenQnt':'count'
                                                        ,'Vader_Compound':'mean'
                                                        ,'Vader_Average': 'mean'
                                                        ,'HVPositive':'sum'
                                                        ,'HVNegative':'sum'
                                                        ,'HVTokenQnt':'sum'
                                                        ,'LMPositive':'sum'
                                                        ,'LMNegative':'sum'
                                                        ,'LMTokenQnt':'sum'
                                                        })

# %%
DailyData['WNSentiment'] =  DailyData['WNSentiAvg']/ DailyData['WNTokenQnt']
DailyData['HVSentiment'] = (DailyData['HVPositive'] - DailyData['HVNegative'])/DailyData['HVTokenQnt']
DailyData['LMSentiment'] = (DailyData['LMPositive'] - DailyData['LMNegative'])/DailyData['LMTokenQnt']

Monthly_Data['WNSentiment'] =  Monthly_Data['WNSentiAvg']/ Monthly_Data['WNTokenQnt']
Monthly_Data['HVSentiment'] = (Monthly_Data['HVPositive'] - Monthly_Data['HVNegative'])/Monthly_Data['HVTokenQnt']
Monthly_Data['LMSentiment'] = (Monthly_Data['LMPositive'] - Monthly_Data['LMNegative'])/Monthly_Data['LMTokenQnt']

# %%
print('Results of Dickey-Fuller Test:')
dftest = adfuller(DailyData['WNSentiment'].dropna(), autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
for i in range(len(dfoutput)):
    dfoutput[i] = round(dfoutput[i],4)
print(dfoutput)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   -6.6105
# p-value                           0.0000
# #Lags Used                       27.0000
# Number of Observations Used    2709.0000
# Critical Value (1%)              -3.4328
# Critical Value (5%)              -2.8626
# Critical Value (10%)             -2.5673
# dtype: float64

# %%
print('Results of Dickey-Fuller Test:')
dftest = adfuller(DailyData['HVSentiment'].dropna(), autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
for i in range(len(dfoutput)):
    dfoutput[i] = round(dfoutput[i],4)
print(dfoutput)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   -6.5368
# p-value                           0.0000
# #Lags Used                       25.0000
# Number of Observations Used    2711.0000
# Critical Value (1%)              -3.4328
# Critical Value (5%)              -2.8626
# Critical Value (10%)             -2.5673
# dtype: float64

# %%
for i in range(len(dfoutput)):
    dfoutput[i] = round(dfoutput[i],4)
print(dfoutput)
print('Results of Dickey-Fuller Test:')
dftest = adfuller(DailyData['LMSentiment'].dropna(), autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
# Out:
# Test Statistic                   -6.5368
# p-value                           0.0000
# #Lags Used                       25.0000
# Number of Observations Used    2711.0000
# Critical Value (1%)              -3.4328
# Critical Value (5%)              -2.8626
# Critical Value (10%)             -2.5673
# dtype: float64
# Results of Dickey-Fuller Test:

# %%
for i in range(len(dfoutput)):
    dfoutput[i] = round(dfoutput[i],4)
print(dfoutput)
print('Results of Dickey-Fuller Test:')
dftest = adfuller(DailyData['Vader_Compound'].dropna(), autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
# Out:
# Test Statistic                   -5.1957
# p-value                           0.0000
# #Lags Used                       28.0000
# Number of Observations Used    2708.0000
# Critical Value (1%)              -3.4328
# Critical Value (5%)              -2.8626
# Critical Value (10%)             -2.5673
# dtype: float64
# Results of Dickey-Fuller Test:

# %%
DailyData.head()
# Out:
#             WNSentiAvg  WNTokenQnt  Vader_Compound  Vader_Average  HVPositive  \
# DateDay
# 2011-06-17    0.000000           4        0.124575         0.0330           3
# 2011-06-20    0.187500           1        0.636900         0.3180           2
# 2011-06-21    0.000000           2       -0.411250        -0.0945           1
# 2011-06-22    0.086538           2        0.461400         0.1830           0
# 2011-06-23    0.000613           2        0.473450         0.1575           5
#
#             HVNegative  HVTokenQnt  LMPositive  LMNegative  LMTokenQnt  \
# DateDay
# 2011-06-17           1          50           1           0          50
# 2011-06-20           0           5           0           0           5
# 2011-06-21           3          31           0           0          31
# 2011-06-22           2          15           0           0          15
# 2011-06-23           3          28           0           1          28
#
#             WNSentiment  HVSentiment  LMSentiment
# DateDay
# 2011-06-17     0.000000     0.040000     0.020000
# 2011-06-20     0.187500     0.400000     0.000000
# 2011-06-21     0.000000    -0.064516     0.000000
# 2011-06-22     0.043269    -0.133333     0.000000
# 2011-06-23     0.000306     0.071429    -0.035714

# %%
Monthly_Data[['Vader_Compound','WNSentiment','HVSentiment','LMSentiment','Vader_Average']].plot(legend=True, figsize=(16,9))

# %% [markdown]
# ## Download S&P from Yahoo

# %%
SnP_daily = web.get_data_yahoo('^GSPC','01/01/2010','05/01/2021',interval='d')
SnP_monthly = web.get_data_yahoo('^GSPC','01/01/2010','05/01/2021',interval='m')

# %%
SnP_daily['LogReturn'] = np.log(SnP_daily['Adj Close']/SnP_daily['Adj Close'].shift(1))

# %%
SnP_monthly.index = SnP_monthly.index.strftime('%Y-%m')

# %%
SnP_monthly['LogReturn'] = np.log(SnP_monthly['Adj Close']/SnP_monthly['Adj Close'].shift(1))

# %% [markdown]
# ## Granger test

# %%
Granger_data_daily = pd.merge(SnP_daily,DailyData, how= 'inner', left_index=True, right_index=True)

# %%
def grangerTest(exog, endog):
    MAX_LAG = 30
    ARaic = AR(exog.tolist()).fit(maxlag=MAX_LAG, ic="aic")
    ARbic = AR(exog.tolist()).fit(maxlag=MAX_LAG, ic="bic")
    # select the fewer number of parameters between both criteria.
    numExog = len(ARaic.params) if len(ARaic.params) < len(ARbic.params) else len(ARbic.params)

    print ("Optimal number of lags for exog data is " + str(numExog))

    ARaic = AR(endog.tolist()).fit(maxlag=MAX_LAG, ic="aic")
    ARbic = AR(endog.tolist()).fit(maxlag=MAX_LAG, ic="bic")
    # select the fewer number of parameters between both criteria.
    numEndog = len(ARaic.params) if len(ARaic.params) < len(ARbic.params) else len(ARbic.params)

    print ("Optimal number of lags for endog data is " + str(numEndog))

    # now that I know the optimal number of parameters, I can call the
    # granger causality function of statsmodels.
    data = pd.concat([endog, exog], axis=1)
    print ("\nGranger causality results of indep onto dep")
    results = grangercausalitytests(data, maxlag=numEndog)

    data = pd.concat([exog, endog], axis=1)
    print ("\nGranger causality results of dep onto indep")
    results = grangercausalitytests(data, maxlag=numExog)
    regr = results[2][1]
    print (regr[0].params)
    print (regr[1].params)
    print (regr[1].pvalues)

# %%
Granger_data_monthly = pd.merge(SnP_monthly,Monthly_Data, how= 'inner', left_index=True, right_index=True)

# %%
#Granger_data['SS_LogReturn'] = np.log((Granger_data['SentimentScoreAdj']+1)/(Granger_data['SentimentScoreAdj']+1).shift(1))

# %%
Vars = ["Vader_Compound","Vader_Average","WNSentiment","HVSentiment","LMSentiment"]
for Var in Vars:
    print("\n" + Var + "\n")
    grangerTest(Granger_data_daily[Var], Granger_data_daily['LogReturn'])
# Out:
# Vader_Compound
# C:\Users\Windows\anaconda3\lib\site-packages\statsmodels\tsa\ar_model.py:691: FutureWarning:
# statsmodels.tsa.AR has been deprecated in favor of statsmodels.tsa.AutoReg and
# statsmodels.tsa.SARIMAX.
#
# AutoReg adds the ability to specify exogenous variables, include time trends,
# and add seasonal dummies. The AutoReg API differs from AR since the model is
# treated as immutable, and so the entire specification including the lag
# length must be specified when creating the model. This change is too
# substantial to incorporate into the existing AR api. The function
# ar_select_order performs lag length selection for AutoReg models.
#
# AutoReg only estimates parameters using conditional MLE (OLS). Use SARIMAX to
# estimate ARX and related models using full MLE via the Kalman Filter.
#
# To silence this warning and continue using AR until it is removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.ar_model.AR', FutureWarning)
#
#   warnings.warn(AR_DEPRECATION_WARN, FutureWarning)
# Optimal number of lags for exog data is 4
# Optimal number of lags for endog data is 10
#
# Granger causality results of indep onto dep
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.9843  , p=0.3213  , df_denom=2163, df_num=1
# ssr based chi2 test:   chi2=0.9857  , p=0.3208  , df=1
# likelihood ratio test: chi2=0.9854  , p=0.3209  , df=1
# parameter F test:         F=0.9843  , p=0.3213  , df_denom=2163, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.4664  , p=0.6273  , df_denom=2160, df_num=2
# ssr based chi2 test:   chi2=0.9349  , p=0.6266  , df=2
# likelihood ratio test: chi2=0.9347  , p=0.6267  , df=2
# parameter F test:         F=0.4664  , p=0.6273  , df_denom=2160, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.5504  , p=0.6479  , df_denom=2157, df_num=3
# ssr based chi2 test:   chi2=1.6567  , p=0.6466  , df=3
# likelihood ratio test: chi2=1.6561  , p=0.6467  , df=3
# parameter F test:         F=0.5504  , p=0.6479  , df_denom=2157, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.8603  , p=0.4871  , df_denom=2154, df_num=4
# ssr based chi2 test:   chi2=3.4554  , p=0.4847  , df=4
# likelihood ratio test: chi2=3.4526  , p=0.4851  , df=4
# parameter F test:         F=0.8603  , p=0.4871  , df_denom=2154, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.8191  , p=0.5359  , df_denom=2151, df_num=5
# ssr based chi2 test:   chi2=4.1164  , p=0.5328  , df=5
# likelihood ratio test: chi2=4.1125  , p=0.5333  , df=5
# parameter F test:         F=0.8191  , p=0.5359  , df_denom=2151, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.7499  , p=0.6095  , df_denom=2148, df_num=6
# ssr based chi2 test:   chi2=4.5266  , p=0.6058  , df=6
# likelihood ratio test: chi2=4.5219  , p=0.6064  , df=6
# parameter F test:         F=0.7499  , p=0.6095  , df_denom=2148, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.6221  , p=0.7380  , df_denom=2145, df_num=7
# ssr based chi2 test:   chi2=4.3853  , p=0.7345  , df=7
# likelihood ratio test: chi2=4.3809  , p=0.7350  , df=7
# parameter F test:         F=0.6221  , p=0.7380  , df_denom=2145, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.5627  , p=0.8091  , df_denom=2142, df_num=8
# ssr based chi2 test:   chi2=4.5373  , p=0.8057  , df=8
# likelihood ratio test: chi2=4.5325  , p=0.8062  , df=8
# parameter F test:         F=0.5627  , p=0.8091  , df_denom=2142, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.6118  , p=0.7880  , df_denom=2139, df_num=9
# ssr based chi2 test:   chi2=5.5550  , p=0.7835  , df=9
# likelihood ratio test: chi2=5.5478  , p=0.7842  , df=9
# parameter F test:         F=0.6118  , p=0.7880  , df_denom=2139, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.5676  , p=0.8415  , df_denom=2136, df_num=10
# ssr based chi2 test:   chi2=5.7315  , p=0.8373  , df=10
# likelihood ratio test: chi2=5.7239  , p=0.8379  , df=10
# parameter F test:         F=0.5676  , p=0.8415  , df_denom=2136, df_num=10
#
# Granger causality results of dep onto indep
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0972  , p=0.7553  , df_denom=2163, df_num=1
# ssr based chi2 test:   chi2=0.0973  , p=0.7551  , df=1
# likelihood ratio test: chi2=0.0973  , p=0.7551  , df=1
# parameter F test:         F=0.0972  , p=0.7553  , df_denom=2163, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.0653  , p=0.9368  , df_denom=2160, df_num=2
# ssr based chi2 test:   chi2=0.1308  , p=0.9367  , df=2
# likelihood ratio test: chi2=0.1308  , p=0.9367  , df=2
# parameter F test:         F=0.0653  , p=0.9368  , df_denom=2160, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3031  , p=0.8232  , df_denom=2157, df_num=3
# ssr based chi2 test:   chi2=0.9122  , p=0.8225  , df=3
# likelihood ratio test: chi2=0.9120  , p=0.8225  , df=3
# parameter F test:         F=0.3031  , p=0.8232  , df_denom=2157, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5002  , p=0.7356  , df_denom=2154, df_num=4
# ssr based chi2 test:   chi2=2.0093  , p=0.7340  , df=4
# likelihood ratio test: chi2=2.0084  , p=0.7342  , df=4
# parameter F test:         F=0.5002  , p=0.7356  , df_denom=2154, df_num=4
# [0.12139764 0.05859631 0.01383547]
# [ 0.12135801  0.05862225  0.11595333 -0.13953798  0.01384766]
# [1.77402533e-08 6.40641524e-03 8.34708331e-01 8.01721109e-01
#  2.41357616e-02]
#
# Vader_Average
#
# Optimal number of lags for exog data is 4
# Optimal number of lags for endog data is 10
#
# Granger causality results of indep onto dep
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3322  , p=0.5644  , df_denom=2163, df_num=1
# ssr based chi2 test:   chi2=0.3327  , p=0.5641  , df=1
# likelihood ratio test: chi2=0.3327  , p=0.5641  , df=1
# parameter F test:         F=0.3322  , p=0.5644  , df_denom=2163, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1942  , p=0.8235  , df_denom=2160, df_num=2
# ssr based chi2 test:   chi2=0.3894  , p=0.8231  , df=2
# likelihood ratio test: chi2=0.3893  , p=0.8231  , df=2
# parameter F test:         F=0.1942  , p=0.8235  , df_denom=2160, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2773  , p=0.8418  , df_denom=2157, df_num=3
# ssr based chi2 test:   chi2=0.8345  , p=0.8412  , df=3
# likelihood ratio test: chi2=0.8344  , p=0.8412  , df=3
# parameter F test:         F=0.2773  , p=0.8418  , df_denom=2157, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.8526  , p=0.4918  , df_denom=2154, df_num=4
# ssr based chi2 test:   chi2=3.4248  , p=0.4894  , df=4
# likelihood ratio test: chi2=3.4221  , p=0.4898  , df=4
# parameter F test:         F=0.8526  , p=0.4918  , df_denom=2154, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.6171  , p=0.6868  , df_denom=2151, df_num=5
# ssr based chi2 test:   chi2=3.1011  , p=0.6844  , df=5
# likelihood ratio test: chi2=3.0989  , p=0.6847  , df=5
# parameter F test:         F=0.6171  , p=0.6868  , df_denom=2151, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.6073  , p=0.7247  , df_denom=2148, df_num=6
# ssr based chi2 test:   chi2=3.6658  , p=0.7218  , df=6
# likelihood ratio test: chi2=3.6626  , p=0.7222  , df=6
# parameter F test:         F=0.6073  , p=0.7247  , df_denom=2148, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.4992  , p=0.8357  , df_denom=2145, df_num=7
# ssr based chi2 test:   chi2=3.5188  , p=0.8332  , df=7
# likelihood ratio test: chi2=3.5160  , p=0.8335  , df=7
# parameter F test:         F=0.4992  , p=0.8357  , df_denom=2145, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.5017  , p=0.8557  , df_denom=2142, df_num=8
# ssr based chi2 test:   chi2=4.0456  , p=0.8530  , df=8
# likelihood ratio test: chi2=4.0418  , p=0.8533  , df=8
# parameter F test:         F=0.5017  , p=0.8557  , df_denom=2142, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.4506  , p=0.9075  , df_denom=2139, df_num=9
# ssr based chi2 test:   chi2=4.0913  , p=0.9053  , df=9
# likelihood ratio test: chi2=4.0875  , p=0.9056  , df=9
# parameter F test:         F=0.4506  , p=0.9075  , df_denom=2139, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.4638  , p=0.9138  , df_denom=2136, df_num=10
# ssr based chi2 test:   chi2=4.6834  , p=0.9113  , df=10
# likelihood ratio test: chi2=4.6783  , p=0.9116  , df=10
# parameter F test:         F=0.4638  , p=0.9138  , df_denom=2136, df_num=10
#
# Granger causality results of dep onto indep
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.4278  , p=0.5132  , df_denom=2163, df_num=1
# ssr based chi2 test:   chi2=0.4284  , p=0.5128  , df=1
# likelihood ratio test: chi2=0.4283  , p=0.5128  , df=1
# parameter F test:         F=0.4278  , p=0.5132  , df_denom=2163, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2866  , p=0.7509  , df_denom=2160, df_num=2
# ssr based chi2 test:   chi2=0.5745  , p=0.7503  , df=2
# likelihood ratio test: chi2=0.5744  , p=0.7504  , df=2
# parameter F test:         F=0.2866  , p=0.7509  , df_denom=2160, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.7768  , p=0.5069  , df_denom=2157, df_num=3
# ssr based chi2 test:   chi2=2.3379  , p=0.5053  , df=3
# likelihood ratio test: chi2=2.3366  , p=0.5055  , df=3
# parameter F test:         F=0.7768  , p=0.5069  , df_denom=2157, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7576  , p=0.5528  , df_denom=2154, df_num=4
# ssr based chi2 test:   chi2=3.0432  , p=0.5506  , df=4
# likelihood ratio test: chi2=3.0411  , p=0.5510  , df=4
# parameter F test:         F=0.7576  , p=0.5528  , df_denom=2154, df_num=4
# [0.11091671 0.0614373  0.00319729]
# [ 0.1109224   0.06143943  0.09553799 -0.08043975  0.00318932]
# [2.46232486e-07 4.18252555e-03 6.00752864e-01 6.59526337e-01
#  1.13366131e-01]
#
# WNSentiment
# Optimal number of lags for exog data is 4
# Optimal number of lags for endog data is 10
#
# Granger causality results of indep onto dep
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.5562  , p=0.4559  , df_denom=2163, df_num=1
# ssr based chi2 test:   chi2=0.5570  , p=0.4555  , df=1
# likelihood ratio test: chi2=0.5569  , p=0.4555  , df=1
# parameter F test:         F=0.5562  , p=0.4559  , df_denom=2163, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.8843  , p=0.4132  , df_denom=2160, df_num=2
# ssr based chi2 test:   chi2=1.7726  , p=0.4122  , df=2
# likelihood ratio test: chi2=1.7719  , p=0.4123  , df=2
# parameter F test:         F=0.8843  , p=0.4132  , df_denom=2160, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.5934  , p=0.1890  , df_denom=2157, df_num=3
# ssr based chi2 test:   chi2=4.7956  , p=0.1874  , df=3
# likelihood ratio test: chi2=4.7903  , p=0.1878  , df=3
# parameter F test:         F=1.5934  , p=0.1890  , df_denom=2157, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.3607  , p=0.2452  , df_denom=2154, df_num=4
# ssr based chi2 test:   chi2=5.4656  , p=0.2428  , df=4
# likelihood ratio test: chi2=5.4587  , p=0.2434  , df=4
# parameter F test:         F=1.3607  , p=0.2452  , df_denom=2154, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.2569  , p=0.2799  , df_denom=2151, df_num=5
# ssr based chi2 test:   chi2=6.3168  , p=0.2766  , df=5
# likelihood ratio test: chi2=6.3076  , p=0.2774  , df=5
# parameter F test:         F=1.2569  , p=0.2799  , df_denom=2151, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.0135  , p=0.4145  , df_denom=2148, df_num=6
# ssr based chi2 test:   chi2=6.1179  , p=0.4101  , df=6
# likelihood ratio test: chi2=6.1092  , p=0.4111  , df=6
# parameter F test:         F=1.0135  , p=0.4145  , df_denom=2148, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.4337  , p=0.1872  , df_denom=2145, df_num=7
# ssr based chi2 test:   chi2=10.1059 , p=0.1827  , df=7
# likelihood ratio test: chi2=10.0823 , p=0.1840  , df=7
# parameter F test:         F=1.4337  , p=0.1872  , df_denom=2145, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.1094  , p=0.3534  , df_denom=2142, df_num=8
# ssr based chi2 test:   chi2=8.9460  , p=0.3469  , df=8
# likelihood ratio test: chi2=8.9275  , p=0.3484  , df=8
# parameter F test:         F=1.1094  , p=0.3534  , df_denom=2142, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.1197  , p=0.3448  , df_denom=2139, df_num=9
# ssr based chi2 test:   chi2=10.1668 , p=0.3371  , df=9
# likelihood ratio test: chi2=10.1430 , p=0.3390  , df=9
# parameter F test:         F=1.1197  , p=0.3448  , df_denom=2139, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.2181  , p=0.2739  , df_denom=2136, df_num=10
# ssr based chi2 test:   chi2=12.3010 , p=0.2654  , df=10
# likelihood ratio test: chi2=12.2660 , p=0.2676  , df=10
# parameter F test:         F=1.2181  , p=0.2739  , df_denom=2136, df_num=10
#
# Granger causality results of dep onto indep
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.7274  , p=0.0537  , df_denom=2163, df_num=1
# ssr based chi2 test:   chi2=3.7326  , p=0.0534  , df=1
# likelihood ratio test: chi2=3.7294  , p=0.0535  , df=1
# parameter F test:         F=3.7274  , p=0.0537  , df_denom=2163, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.5309  , p=0.0294  , df_denom=2160, df_num=2
# ssr based chi2 test:   chi2=7.0782  , p=0.0290  , df=2
# likelihood ratio test: chi2=7.0667  , p=0.0292  , df=2
# parameter F test:         F=3.5309  , p=0.0294  , df_denom=2160, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.1457  , p=0.0242  , df_denom=2157, df_num=3
# ssr based chi2 test:   chi2=9.4679  , p=0.0237  , df=3
# likelihood ratio test: chi2=9.4472  , p=0.0239  , df=3
# parameter F test:         F=3.1457  , p=0.0242  , df_denom=2157, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.3948  , p=0.0485  , df_denom=2154, df_num=4
# ssr based chi2 test:   chi2=9.6191  , p=0.0474  , df=4
# likelihood ratio test: chi2=9.5978  , p=0.0478  , df=4
# parameter F test:         F=2.3948  , p=0.0485  , df_denom=2154, df_num=4
# [0.06980411 0.07023952 0.0067875 ]
# [0.06652602 0.07033376 0.162075   0.1236528  0.00666559]
# [1.85335133e-03 9.86570326e-04 2.20019262e-02 8.06859963e-02
#  3.59297273e-16]
#
# HVSentiment
#
# Optimal number of lags for exog data is 4
# Optimal number of lags for endog data is 10
#
# Granger causality results of indep onto dep
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=5.4622  , p=0.0195  , df_denom=2163, df_num=1
# ssr based chi2 test:   chi2=5.4698  , p=0.0193  , df=1
# likelihood ratio test: chi2=5.4629  , p=0.0194  , df=1
# parameter F test:         F=5.4622  , p=0.0195  , df_denom=2163, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.5200  , p=0.0807  , df_denom=2160, df_num=2
# ssr based chi2 test:   chi2=5.0516  , p=0.0800  , df=2
# likelihood ratio test: chi2=5.0457  , p=0.0802  , df=2
# parameter F test:         F=2.5200  , p=0.0807  , df_denom=2160, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.8524  , p=0.1356  , df_denom=2157, df_num=3
# ssr based chi2 test:   chi2=5.5752  , p=0.1342  , df=3
# likelihood ratio test: chi2=5.5680  , p=0.1346  , df=3
# parameter F test:         F=1.8524  , p=0.1356  , df_denom=2157, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.3484  , p=0.2496  , df_denom=2154, df_num=4
# ssr based chi2 test:   chi2=5.4162  , p=0.2472  , df=4
# likelihood ratio test: chi2=5.4094  , p=0.2478  , df=4
# parameter F test:         F=1.3484  , p=0.2496  , df_denom=2154, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.9557  , p=0.4437  , df_denom=2151, df_num=5
# ssr based chi2 test:   chi2=4.8031  , p=0.4404  , df=5
# likelihood ratio test: chi2=4.7978  , p=0.4410  , df=5
# parameter F test:         F=0.9557  , p=0.4437  , df_denom=2151, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.9463  , p=0.4605  , df_denom=2148, df_num=6
# ssr based chi2 test:   chi2=5.7122  , p=0.4562  , df=6
# likelihood ratio test: chi2=5.7046  , p=0.4571  , df=6
# parameter F test:         F=0.9463  , p=0.4605  , df_denom=2148, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.8132  , p=0.5762  , df_denom=2145, df_num=7
# ssr based chi2 test:   chi2=5.7325  , p=0.5713  , df=7
# likelihood ratio test: chi2=5.7249  , p=0.5722  , df=7
# parameter F test:         F=0.8132  , p=0.5762  , df_denom=2145, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.7550  , p=0.6428  , df_denom=2142, df_num=8
# ssr based chi2 test:   chi2=6.0878  , p=0.6374  , df=8
# likelihood ratio test: chi2=6.0792  , p=0.6384  , df=8
# parameter F test:         F=0.7550  , p=0.6428  , df_denom=2142, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.6901  , p=0.7185  , df_denom=2139, df_num=9
# ssr based chi2 test:   chi2=6.2663  , p=0.7130  , df=9
# likelihood ratio test: chi2=6.2572  , p=0.7139  , df=9
# parameter F test:         F=0.6901  , p=0.7185  , df_denom=2139, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.6224  , p=0.7959  , df_denom=2136, df_num=10
# ssr based chi2 test:   chi2=6.2851  , p=0.7908  , df=10
# likelihood ratio test: chi2=6.2759  , p=0.7916  , df=10
# parameter F test:         F=0.6224  , p=0.7959  , df_denom=2136, df_num=10
#
# Granger causality results of dep onto indep
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.7103  , p=0.3994  , df_denom=2163, df_num=1
# ssr based chi2 test:   chi2=0.7113  , p=0.3990  , df=1
# likelihood ratio test: chi2=0.7111  , p=0.3991  , df=1
# parameter F test:         F=0.7103  , p=0.3994  , df_denom=2163, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3405  , p=0.7115  , df_denom=2160, df_num=2
# ssr based chi2 test:   chi2=0.6825  , p=0.7109  , df=2
# likelihood ratio test: chi2=0.6824  , p=0.7109  , df=2
# parameter F test:         F=0.3405  , p=0.7115  , df_denom=2160, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2641  , p=0.8513  , df_denom=2157, df_num=3
# ssr based chi2 test:   chi2=0.7950  , p=0.8507  , df=3
# likelihood ratio test: chi2=0.7948  , p=0.8507  , df=3
# parameter F test:         F=0.2641  , p=0.8513  , df_denom=2157, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.9155  , p=0.4539  , df_denom=2154, df_num=4
# ssr based chi2 test:   chi2=3.6772  , p=0.4515  , df=4
# likelihood ratio test: chi2=3.6740  , p=0.4519  , df=4
# parameter F test:         F=0.9155  , p=0.4539  , df_denom=2154, df_num=4
# [0.12609512 0.04078904 0.00412914]
# [0.12542351 0.03986832 0.13042144 0.05490725 0.00404172]
# [5.33802786e-09 6.29761397e-02 4.22218573e-01 7.35298665e-01
#  2.41831159e-02]
#
# LMSentiment
# Optimal number of lags for exog data is 8
# Optimal number of lags for endog data is 10
#
# Granger causality results of indep onto dep
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.3546  , p=0.2446  , df_denom=2163, df_num=1
# ssr based chi2 test:   chi2=1.3565  , p=0.2441  , df=1
# likelihood ratio test: chi2=1.3561  , p=0.2442  , df=1
# parameter F test:         F=1.3546  , p=0.2446  , df_denom=2163, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.6321  , p=0.5316  , df_denom=2160, df_num=2
# ssr based chi2 test:   chi2=1.2671  , p=0.5307  , df=2
# likelihood ratio test: chi2=1.2668  , p=0.5308  , df=2
# parameter F test:         F=0.6321  , p=0.5316  , df_denom=2160, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.2774  , p=0.2805  , df_denom=2157, df_num=3
# ssr based chi2 test:   chi2=3.8446  , p=0.2787  , df=3
# likelihood ratio test: chi2=3.8412  , p=0.2791  , df=3
# parameter F test:         F=1.2774  , p=0.2805  , df_denom=2157, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.0330  , p=0.3887  , df_denom=2154, df_num=4
# ssr based chi2 test:   chi2=4.1493  , p=0.3862  , df=4
# likelihood ratio test: chi2=4.1454  , p=0.3867  , df=4
# parameter F test:         F=1.0330  , p=0.3887  , df_denom=2154, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.9382  , p=0.4550  , df_denom=2151, df_num=5
# ssr based chi2 test:   chi2=4.7149  , p=0.4517  , df=5
# likelihood ratio test: chi2=4.7098  , p=0.4523  , df=5
# parameter F test:         F=0.9382  , p=0.4550  , df_denom=2151, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.7295  , p=0.6259  , df_denom=2148, df_num=6
# ssr based chi2 test:   chi2=4.4032  , p=0.6223  , df=6
# likelihood ratio test: chi2=4.3988  , p=0.6229  , df=6
# parameter F test:         F=0.7295  , p=0.6259  , df_denom=2148, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.6295  , p=0.7318  , df_denom=2145, df_num=7
# ssr based chi2 test:   chi2=4.4377  , p=0.7282  , df=7
# likelihood ratio test: chi2=4.4331  , p=0.7288  , df=7
# parameter F test:         F=0.6295  , p=0.7318  , df_denom=2145, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.7714  , p=0.6280  , df_denom=2142, df_num=8
# ssr based chi2 test:   chi2=6.2205  , p=0.6225  , df=8
# likelihood ratio test: chi2=6.2116  , p=0.6235  , df=8
# parameter F test:         F=0.7714  , p=0.6280  , df_denom=2142, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.9549  , p=0.4759  , df_denom=2139, df_num=9
# ssr based chi2 test:   chi2=8.6700  , p=0.4683  , df=9
# likelihood ratio test: chi2=8.6527  , p=0.4699  , df=9
# parameter F test:         F=0.9549  , p=0.4759  , df_denom=2139, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.8840  , p=0.5475  , df_denom=2136, df_num=10
# ssr based chi2 test:   chi2=8.9271  , p=0.5390  , df=10
# likelihood ratio test: chi2=8.9086  , p=0.5408  , df=10
# parameter F test:         F=0.8840  , p=0.5475  , df_denom=2136, df_num=10
#
# Granger causality results of dep onto indep
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.1327  , p=0.1443  , df_denom=2163, df_num=1
# ssr based chi2 test:   chi2=2.1356  , p=0.1439  , df=1
# likelihood ratio test: chi2=2.1346  , p=0.1440  , df=1
# parameter F test:         F=2.1327  , p=0.1443  , df_denom=2163, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.0451  , p=0.3518  , df_denom=2160, df_num=2
# ssr based chi2 test:   chi2=2.0950  , p=0.3508  , df=2
# likelihood ratio test: chi2=2.0940  , p=0.3510  , df=2
# parameter F test:         F=1.0451  , p=0.3518  , df_denom=2160, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.7830  , p=0.5034  , df_denom=2157, df_num=3
# ssr based chi2 test:   chi2=2.3565  , p=0.5018  , df=3
# likelihood ratio test: chi2=2.3552  , p=0.5020  , df=3
# parameter F test:         F=0.7830  , p=0.5034  , df_denom=2157, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.6659  , p=0.6157  , df_denom=2154, df_num=4
# ssr based chi2 test:   chi2=2.6746  , p=0.6137  , df=4
# likelihood ratio test: chi2=2.6730  , p=0.6140  , df=4
# parameter F test:         F=0.6659  , p=0.6157  , df_denom=2154, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.5364  , p=0.7489  , df_denom=2151, df_num=5
# ssr based chi2 test:   chi2=2.6956  , p=0.7468  , df=5
# likelihood ratio test: chi2=2.6939  , p=0.7471  , df=5
# parameter F test:         F=0.5364  , p=0.7489  , df_denom=2151, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.4889  , p=0.8171  , df_denom=2148, df_num=6
# ssr based chi2 test:   chi2=2.9509  , p=0.8150  , df=6
# likelihood ratio test: chi2=2.9489  , p=0.8152  , df=6
# parameter F test:         F=0.4889  , p=0.8171  , df_denom=2148, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.4388  , p=0.8781  , df_denom=2145, df_num=7
# ssr based chi2 test:   chi2=3.0934  , p=0.8762  , df=7
# likelihood ratio test: chi2=3.0912  , p=0.8764  , df=7
# parameter F test:         F=0.4388  , p=0.8781  , df_denom=2145, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.4232  , p=0.9077  , df_denom=2142, df_num=8
# ssr based chi2 test:   chi2=3.4124  , p=0.9059  , df=8
# likelihood ratio test: chi2=3.4097  , p=0.9061  , df=8
# parameter F test:         F=0.4232  , p=0.9077  , df_denom=2142, df_num=8
# [ 0.08217193  0.09337327 -0.02602869]
# [ 0.08138068  0.09260972  0.13404867  0.04126539 -0.02616821]
# [1.49864211e-04 1.59688901e-05 1.51501290e-01 6.58883564e-01
#  1.26936846e-74]

# %%
Granger_data_monthly[['LogReturn','Vader_Average','Vader_Compound','HVSentiment']].plot(legend=True, figsize=(16,9))

# %%
corr = Granger_data_daily[["Vader_Compound","Vader_Average","WNSentiment","HVSentiment","LMSentiment", 'LogReturn']].corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow0_col1 {
#             background-color:  #d0473d;
#             color:  #f1f1f1;
#         }    #T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow0_col2 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow0_col3 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow0_col4 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow0_col5 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow1_col0 {
#             background-color:  #d0473d;
#             color:  #f1f1f1;
#         }    #T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow1_col2 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow1_col3 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow1_col4 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow2_col0 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow2_col1 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow2_col3 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow2_col4 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow2_col5 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow3_col0 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow3_col1 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow3_col2 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow3_col4 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow3_col5 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow4_col0 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow4_col1 {
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }    #T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow4_col2 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow4_col3 {
#             background-color:  #dadce0;
#             color:  #000000;
#         }    #T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow4_col5 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow5_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow5_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow5_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow5_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow5_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65ce" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Vader_Compound</th>        <th class="col_heading level0 col1" >Vader_Average</th>        <th class="col_heading level0 col2" >WNSentiment</th>        <th class="col_heading level0 col3" >HVSentiment</th>        <th class="col_heading level0 col4" >LMSentiment</th>        <th class="col_heading level0 col5" >LogReturn</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65celevel0_row0" class="row_heading level0 row0" >Vader_Compound</th>
#                         <td id="T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow0_col1" class="data row0 col1" >0.921830</td>
#                         <td id="T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow0_col2" class="data row0 col2" >0.357260</td>
#                         <td id="T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow0_col3" class="data row0 col3" >0.442596</td>
#                         <td id="T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow0_col4" class="data row0 col4" >0.462694</td>
#                         <td id="T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow0_col5" class="data row0 col5" >0.019388</td>
#             </tr>
#             <tr>
#                         <th id="T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65celevel0_row1" class="row_heading level0 row1" >Vader_Average</th>
#                         <td id="T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow1_col0" class="data row1 col0" >0.921830</td>
#                         <td id="T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow1_col2" class="data row1 col2" >0.373643</td>
#                         <td id="T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow1_col3" class="data row1 col3" >0.440092</td>
#                         <td id="T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow1_col4" class="data row1 col4" >0.466188</td>
#                         <td id="T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow1_col5" class="data row1 col5" >0.012869</td>
#             </tr>
#             <tr>
#                         <th id="T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65celevel0_row2" class="row_heading level0 row2" >WNSentiment</th>
#                         <td id="T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow2_col0" class="data row2 col0" >0.357260</td>
#                         <td id="T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow2_col1" class="data row2 col1" >0.373643</td>
#                         <td id="T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow2_col3" class="data row2 col3" >0.257678</td>
#                         <td id="T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow2_col4" class="data row2 col4" >0.265665</td>
#                         <td id="T_d1e762f6_dc04_11eb_b1d9_4ccc6adc65cerow2_col5" class="data row2 col5" >0.032583</td>
#             </tr>
#             <tr>

# %%
pvals = [] 
for col in ["Vader_Compound","Vader_Average","WNSentiment","HVSentiment","LMSentiment"]:
    pvals.append(scipy.stats.linregress(Granger_data_daily['LogReturn'][1:], Granger_data_daily[col][1:].dropna())[3])
corr_signif = pd.DataFrame(pvals,columns = ['p-value']
                           ,index = ["Vader_Compound","Vader_Average","WNSentiment","HVSentiment","LMSentiment"])
#print(corr_signif.to_latex())
print(corr_signif)
# Out:
#                  p-value
# Vader_Compound  0.368055
# Vader_Average   0.550431
# WNSentiment     0.129251
# HVSentiment     0.091979
# LMSentiment     0.412993

# %%
pvals_mnt = [] 
for col in ['Vader_Compound','Flair_Score','SentimentScoreAdj','Vader_Average']:
    pvals_mnt.append(scipy.stats.linregress(Granger_data_monthly['LogReturn'][1:], Granger_data_monthly[col][1:].dropna())[3])
corr_signif_mnt = pd.DataFrame(pvals_mnt,columns = ['p-value']
                           ,index = ['Vader_Compound','Flair_Score','SentimentScoreAdj','Vader_Average'])
corr_signif_mnt
# Out:
#                     p-value
# Vader_Compound     0.084306
# Flair_Score        0.977764
# SentimentScoreAdj  0.311650
# Vader_Average      0.047369
