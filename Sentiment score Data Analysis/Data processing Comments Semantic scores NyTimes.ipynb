# %%
import csv
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
import pandas_datareader.data as web
import statsmodels.api as sm
from statsmodels.tsa.stattools import grangercausalitytests
from matplotlib import pyplot
import scipy.stats
from statsmodels.tsa.stattools import adfuller
from yahoofinancials import YahooFinancials
from statsmodels.tsa.ar_model import AR
# %matplotlib inline

# %%
fpath = 'facebook_data_nytimes_comments_sentiment_4dict.tsv'
post_data = pd.read_csv(fpath, sep='\t')
post_data.head()
# Out:
#    ID        PostID                    PostDate          CommentID  \
# 0   0  1.015271e+16  2021-06-13 14:39:05.828562  10152706166884999
# 1   1  1.015271e+16  2021-06-13 14:39:05.828562  10152706181999999
# 2   2  1.015271e+16  2021-06-13 14:39:05.828562  10152706167109999
# 3   3  1.015271e+16  2021-06-13 14:39:05.828562  10152706182414999
# 4   4  1.015271e+16  2021-06-13 14:39:05.828562  10152706185829999
#
#                   CommentDate  \
# 0  2021-06-13 14:39:39.092970
# 1  2021-06-13 15:39:39.494895
# 2  2021-06-13 14:39:39.936749
# 3  2021-06-13 15:39:40.326378
# 4  2021-06-13 15:39:40.719285
#
#                                         CommenterURL  \
# 0   jessica.mulcahy.5?fref=nf&rc=p&refid=52&__tn__=R
# 1   profile.php?id=100010824877389&fref=nf&rc=p&r...
# 2        austin.given?fref=nf&rc=p&refid=52&__tn__=R
# 3    jessica.vanliere?fref=nf&rc=p&refid=52&__tn__=R
# 4     laura.celidonio?fref=nf&rc=p&refid=52&__tn__=R
#
#                                          CommentText  WNPositive  WNNegative  \
# 0  Isn't it a wonder that a company could theoret...    0.750000    1.000000
# 1  Not where I live. This information would be in...    1.125000    2.625000
# 2          Investing is better than renting. Always.    0.875000    0.000000
# 3  A house 🏠 is a liability, not an asset. The pe...    7.233696    2.418478
# 4  Maybe for the big cities of the world. These m...    2.875000    2.000000
#
#    WNNeutral  ...  HVTokenQnt  HVSentiAvg  LMPositive  LMNegative  LMTokenQnt  \
# 0  12.250000  ...          23    0.304348           1           1          23
# 1  40.250000  ...          45    0.066667           2           2          45
# 2   0.125000  ...           3    0.333333           1           0           3
# 3  46.347826  ...          59   -0.016949           2           1          59
# 4  23.125000  ...          27    0.259259           1           0          27
#
#    LMSentiAvg  Vader_Positive  Vader_Negative  Vader_Neutral  Vader_Compound
# 0    0.000000           0.184           0.137          0.678          0.2960
# 1    0.000000           0.042           0.080          0.878         -0.6588
# 2    0.333333           0.367           0.000          0.633          0.4404
# 3    0.016949           0.142           0.045          0.813          0.9459
# 4    0.037037           0.096           0.025          0.879          0.7469
#
# [5 rows x 25 columns]

# %%
post_data['Vader_Average'] = post_data['Vader_Positive'] - post_data['Vader_Negative']

# %%
bins = np.linspace(-1, 1, 100)
pyplot.hist(post_data['WNSentiAvg'], bins, alpha=0.5, label='WNSentiAvg')
pyplot.hist(post_data['HVSentiAvg'], bins, alpha=0.5, label='HVSentiAvg')
pyplot.hist(post_data['LMSentiAvg'], bins, alpha=0.5, label='LMSentiAvg')
pyplot.hist(post_data['Vader_Compound'], bins, alpha=0.5, label='Vader_Compound')
pyplot.hist(post_data['Vader_Positive'] - post_data['Vader_Negative'], bins, alpha=0.5, label='Vader_Average')
pyplot.legend(loc='upper right')
pyplot.title('Distribution of semantic scores')
pyplot.show()

# %%
# seaborn histogram
sns.distplot((post_data['Vader_Compound'] - post_data['Vader_Compound'].mean())/post_data['Vader_Compound'].std(), hist=False, kde=True, 
             bins=int(180/5), color = 'red',
             hist_kws={'edgecolor':'black'})
sns.distplot((post_data['WNSentiAvg'] - post_data['WNSentiAvg'].mean())/post_data['WNSentiAvg'].std(), hist=False, kde=True, 
             bins=int(180/5), color = 'blue',
             hist_kws={'edgecolor':'black'})
sns.distplot((post_data['LMSentiAvg'] - post_data['LMSentiAvg'].mean())/post_data['LMSentiAvg'].std(), hist=False, kde=True, 
             bins=int(180/5), color = 'green',
             hist_kws={'edgecolor':'black'})
sns.distplot((post_data['HVSentiAvg'] - post_data['HVSentiAvg'].mean())/post_data['HVSentiAvg'].std(), hist=False, kde=True, 
             bins=int(180/5), color = 'orange',
             hist_kws={'edgecolor':'black'})
sns.distplot((post_data['Vader_Average'] - post_data['Vader_Average'].mean())/post_data['Vader_Average'].std(), hist=False, kde=True, 
             bins=int(180/5), color = 'purple',
             hist_kws={'edgecolor':'black'})
# Add labels
plt.title('Distribution of Sentiment Score')
plt.xlabel('Score')
plt.ylabel('Posts')
# Out:
# Text(0, 0.5, 'Posts')

# %%
post_data[['WNSentiAvg','HVSentiAvg','LMSentiAvg','Vader_Compound','Vader_Average']].describe()
# Out:
#           WNSentiAvg     HVSentiAvg     LMSentiAvg  Vader_Compound  \
# count  214602.000000  214602.000000  214602.000000   214602.000000
# mean        0.018138       0.024849      -0.040729        0.022084
# std         0.138283       0.291396       0.150766        0.507221
# min        -1.000000      -1.000000      -1.000000       -0.999700
# 25%        -0.028846      -0.105263      -0.083333       -0.373600
# 50%         0.000000       0.000000       0.000000        0.000000
# 75%         0.062500       0.166667       0.000000        0.440400
# max         1.000000       1.000000       1.000000        0.999700
#
#        Vader_Average
# count  214602.000000
# mean        0.015085
# std         0.235637
# min        -1.000000
# 25%        -0.097000
# 50%         0.000000
# 75%         0.127000
# max         1.000000

# %%
post_data['PostDate'] = pd.to_datetime(post_data['PostDate'], errors='coerce')

post_data['DateMonth'] = post_data['PostDate'].dt.strftime('%Y-%m')
post_data['DateDay'] = post_data['PostDate'].dt.strftime('%Y-%m-%d')

# %%
post_data['DateMonth'].head()
# Out:
# 0    2021-06
# 1    2021-06
# 2    2021-06
# 3    2021-06
# 4    2021-06
# Name: DateMonth, dtype: object

# %%
post_data.columns
# Out:
# Index(['ID', 'PostID', 'PostDate', 'CommentID', 'CommentDate', 'CommenterURL',
#        'CommentText', 'WNPositive', 'WNNegative', 'WNNeutral', 'WNSentiment',
#        'WNTokenQnt', 'WNSentiAvg', 'HVPositive', 'HVNegative', 'HVTokenQnt',
#        'HVSentiAvg', 'LMPositive', 'LMNegative', 'LMTokenQnt', 'LMSentiAvg',
#        'Vader_Positive', 'Vader_Negative', 'Vader_Neutral', 'Vader_Compound',
#        'Vader_Average', 'DateMonth', 'DateDay'],
#       dtype='object')

# %%
Monthly_Data = post_data.groupby('DateMonth').agg({'WNSentiAvg': 'sum'
                                                         ,'WNTokenQnt':'count'
                                                        ,'Vader_Compound':'mean'
                                                        ,'Vader_Average': 'mean'
                                                        ,'HVPositive':'sum'
                                                        ,'HVNegative':'sum'
                                                        ,'HVTokenQnt':'sum'
                                                        ,'LMPositive':'sum'
                                                        ,'LMNegative':'sum'
                                                        ,'LMTokenQnt':'sum'
                                                       })

# %%
DailyData = post_data.groupby('DateDay').agg({'WNSentiAvg': 'sum'
                                                        ,'WNTokenQnt':'count'
                                                        ,'Vader_Compound':'mean'
                                                        ,'Vader_Average': 'mean'
                                                        ,'HVPositive':'sum'
                                                        ,'HVNegative':'sum'
                                                        ,'HVTokenQnt':'sum'
                                                        ,'LMPositive':'sum'
                                                        ,'LMNegative':'sum'
                                                        ,'LMTokenQnt':'sum'
                                                        })

# %%
DailyData['WNSentiment'] =  DailyData['WNSentiAvg']/ DailyData['WNTokenQnt']
DailyData['HVSentiment'] = (DailyData['HVPositive'] - DailyData['HVNegative'])/DailyData['HVTokenQnt']
DailyData['LMSentiment'] = (DailyData['LMPositive'] - DailyData['LMNegative'])/DailyData['LMTokenQnt']

Monthly_Data['WNSentiment'] =  Monthly_Data['WNSentiAvg']/ Monthly_Data['WNTokenQnt']
Monthly_Data['HVSentiment'] = (Monthly_Data['HVPositive'] - Monthly_Data['HVNegative'])/Monthly_Data['HVTokenQnt']
Monthly_Data['LMSentiment'] = (Monthly_Data['LMPositive'] - Monthly_Data['LMNegative'])/Monthly_Data['LMTokenQnt']

# %%
print('Results of Dickey-Fuller Test:')
dftest = adfuller(DailyData['WNSentiment'].dropna(), autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
for i in range(len(dfoutput)):
    dfoutput[i] = round(dfoutput[i],4)
print(dfoutput)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -3.0102
# p-value                          0.0340
# #Lags Used                       6.0000
# Number of Observations Used    209.0000
# Critical Value (1%)             -3.4620
# Critical Value (5%)             -2.8755
# Critical Value (10%)            -2.5742
# dtype: float64

# %%
print('Results of Dickey-Fuller Test:')
dftest = adfuller(DailyData['HVSentiment'].dropna(), autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
for i in range(len(dfoutput)):
    dfoutput[i] = round(dfoutput[i],4)
print(dfoutput)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -10.0990
# p-value                          0.0000
# #Lags Used                       0.0000
# Number of Observations Used    215.0000
# Critical Value (1%)             -3.4611
# Critical Value (5%)             -2.8751
# Critical Value (10%)            -2.5740
# dtype: float64

# %%
for i in range(len(dfoutput)):
    dfoutput[i] = round(dfoutput[i],4)
print(dfoutput)
print('Results of Dickey-Fuller Test:')
dftest = adfuller(DailyData['LMSentiment'].dropna(), autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
# Out:
# Test Statistic                 -10.0990
# p-value                          0.0000
# #Lags Used                       0.0000
# Number of Observations Used    215.0000
# Critical Value (1%)             -3.4611
# Critical Value (5%)             -2.8751
# Critical Value (10%)            -2.5740
# dtype: float64
# Results of Dickey-Fuller Test:

# %%
for i in range(len(dfoutput)):
    dfoutput[i] = round(dfoutput[i],4)
print(dfoutput)
print('Results of Dickey-Fuller Test:')
dftest = adfuller(DailyData['Vader_Compound'].dropna(), autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
# Out:
# Test Statistic                  -2.9641
# p-value                          0.0384
# #Lags Used                       8.0000
# Number of Observations Used    207.0000
# Critical Value (1%)             -3.4623
# Critical Value (5%)             -2.8756
# Critical Value (10%)            -2.5743
# dtype: float64
# Results of Dickey-Fuller Test:

# %%
DailyData.head()
# Out:
#             WNSentiAvg  WNTokenQnt  Vader_Compound  Vader_Average  HVPositive  \
# DateDay
# 2015-09-13    4.601582         115        0.154141       0.116713         248
# 2019-09-29   10.168065         743        0.038492       0.035493        1322
# 2019-09-30    1.812409          57       -0.090011      -0.026298         201
# 2019-11-29    2.517020         145       -0.016368      -0.015338         218
# 2019-11-30   16.443055         905        0.072205       0.040280        1229
#
#             HVNegative  HVTokenQnt  LMPositive  LMNegative  LMTokenQnt  \
# DateDay
# 2015-09-13         173        1763          43          57        1763
# 2019-09-29        1096        6848         154         544        6848
# 2019-09-30         197        1143          25         107        1143
# 2019-11-29         148        1219          25          56        1219
# 2019-11-30         846        6674         183         380        6674
#
#             WNSentiment  HVSentiment  LMSentiment
# DateDay
# 2015-09-13     0.040014     0.042541    -0.007941
# 2019-09-29     0.013685     0.033002    -0.056951
# 2019-09-30     0.031797     0.003500    -0.071741
# 2019-11-29     0.017359     0.057424    -0.025431
# 2019-11-30     0.018169     0.057387    -0.029518

# %%
Monthly_Data[['Vader_Compound','WNSentiment','HVSentiment','LMSentiment','Vader_Average']].plot(legend=True, figsize=(16,9))

# %% [markdown]
# ## Download S&P from Yahoo

# %%
#SnP_daily = web.get_data_yahoo('^GSPC','10/01/2010','05/01/2021',interval='d')
#SnP_monthly = web.get_data_yahoo('^GSPC','10/01/2010','05/01/2021',interval='m')
yahoo_financials = YahooFinancials(['^GSPC']).get_historical_price_data('2019-01-01','2021-05-31','daily')
SnP_daily =pd.DataFrame(yahoo_financials["^GSPC"]["prices"])
SnP_daily.index = SnP_daily['formatted_date']
SnP_daily['LogReturn'] = np.log(SnP_daily['adjclose']/SnP_daily['adjclose'].shift(1))

yahoo_financials_m = YahooFinancials(['^GSPC']).get_historical_price_data('2019-01-01','2021-05-31','monthly')
SnP_monthly =pd.DataFrame(yahoo_financials_m["^GSPC"]["prices"])
SnP_monthly.index = SnP_monthly['formatted_date']
SnP_monthly['LogReturn'] = np.log(SnP_monthly['adjclose']/SnP_monthly['adjclose'].shift(1))

# %%
SnP_daily['LogReturn'] = np.log(SnP_daily['Adj Close']/SnP_daily['Adj Close'].shift(1))

# %%
SnP_monthly.index = SnP_monthly.index.strftime('%Y-%m')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-fb940088bc62> in <module>
# ----> 1 SnP_monthly.index = SnP_monthly.index.strftime('%Y-%m')
#
# AttributeError: 'Index' object has no attribute 'strftime'

# %%
SnP_monthly['LogReturn'] = np.log(SnP_monthly['Adj Close']/SnP_monthly['Adj Close'].shift(1))

# %% [markdown]
# ## Granger test

# %%
Granger_data_daily = pd.merge(SnP_daily,DailyData, how= 'inner', left_index=True, right_index=True)

# %%
def grangerTest(exog, endog):
    MAX_LAG = 30
    ARaic = AR(exog.tolist()).fit(maxlag=MAX_LAG, ic="aic")
    ARbic = AR(exog.tolist()).fit(maxlag=MAX_LAG, ic="bic")
    # select the fewer number of parameters between both criteria.
    numExog = len(ARaic.params) if len(ARaic.params) < len(ARbic.params) else len(ARbic.params)

    print ("Optimal number of lags for exog data is " + str(numExog))

    ARaic = AR(endog.tolist()).fit(maxlag=MAX_LAG, ic="aic")
    ARbic = AR(endog.tolist()).fit(maxlag=MAX_LAG, ic="bic")
    # select the fewer number of parameters between both criteria.
    numEndog = len(ARaic.params) if len(ARaic.params) < len(ARbic.params) else len(ARbic.params)

    print ("Optimal number of lags for endog data is " + str(numEndog))

    # now that I know the optimal number of parameters, I can call the
    # granger causality function of statsmodels.
    data = pd.concat([endog, exog], axis=1)
    print ("\nGranger causality results of indep onto dep")
    results = grangercausalitytests(data, maxlag=numEndog)

    data = pd.concat([exog, endog], axis=1)
    print ("\nGranger causality results of dep onto indep")
    results = grangercausalitytests(data, maxlag=numExog)
    regr = results[2][1]
    print (regr[0].params)
    print (regr[1].params)
    print (regr[1].pvalues)

# %%
Granger_data_monthly = pd.merge(SnP_monthly,Monthly_Data, how= 'inner', left_index=True, right_index=True)

# %%
#Granger_data['SS_LogReturn'] = np.log((Granger_data['SentimentScoreAdj']+1)/(Granger_data['SentimentScoreAdj']+1).shift(1))

# %%
Granger_data_monthly
# Out:
#                 High          Low         Open        Close        Volume  \
# 2011-06  1345.199951  1258.069946  1345.199951  1320.640015   86122730000
# 2011-07  1356.479980  1282.859985  1320.640015  1292.280029   81102170000
# 2011-08  1307.380005  1101.540039  1292.589966  1218.890015  108419170000
# 2011-09  1229.290039  1114.219971  1219.119995  1131.420044  102786820000
# 2011-10  1292.660034  1074.770020  1131.209961  1253.300049   98063670000
# ...              ...          ...          ...          ...           ...
# 2021-01  3870.899902  3662.709961  3764.610107  3714.239990  105548790000
# 2021-02  3950.429932  3725.620117  3731.169922  3811.149902   98596960000
# 2021-03  3994.409912  3723.340088  3842.510010  3972.889893  120863560000
# 2021-04  4218.779785  3992.780029  3992.780029  4181.169922   82869290000
# 2021-05  4238.040039  4056.879883  4191.979980  4204.109863   75155370000
#
#            Adj Close  LogReturn  WNSentiAvg  WNTokenQnt  Vader_Compound  \
# 2011-06  1320.640015  -0.018426    0.000000           1       -0.631000
# 2011-07  1292.280029  -0.021708    0.057692           2        0.484350
# 2011-08  1218.890015  -0.058468    0.102652           7        0.298771
# 2011-09  1131.420044  -0.074467   -0.062500           5       -0.160040
# 2011-10  1253.300049   0.102307    0.053971          10        0.251150
# ...              ...        ...         ...         ...             ...
# 2021-01  3714.239990  -0.011199   76.404470        2123        0.106775
# 2021-02  3811.149902   0.025757   35.554546        1008        0.104644
# 2021-03  3972.889893   0.041563   50.886415        1283        0.160192
# 2021-04  4181.169922   0.051097   31.388089         946        0.111396
# 2021-05  4204.109863   0.005471   67.823295        1394        0.125490
#
#          Vader_Average  HVPositive  HVNegative  HVTokenQnt  LMPositive  \
# 2011-06      -0.165000           0           1           8           0
# 2011-07       0.124500           5           0          26           0
# 2011-08       0.235571          16           5          51           1
# 2011-09      -0.090800           0           6          18           0
# 2011-10       0.100300          21           9          83           3
# ...                ...         ...         ...         ...         ...
# 2021-01       0.047973        3653        2259       19638         603
# 2021-02       0.036783        1739         846        9117         282
# 2021-03       0.072603        2566        1455       13705         413
# 2021-04       0.041881        1853        1109       10004         321
# 2021-05       0.059929        2430        1435       13609         394
#
#          LMNegative  LMTokenQnt  WNSentiment  HVSentiment  LMSentiment
# 2011-06           1           8     0.000000    -0.125000    -0.125000
# 2011-07           0          26     0.028846     0.192308     0.000000
# 2011-08           0          51     0.014665     0.215686     0.019608
# 2011-09           5          18    -0.012500    -0.333333    -0.277778
# 2011-10           6          83     0.005397     0.144578    -0.036145
# ...             ...         ...          ...          ...          ...
# 2021-01         999       19638     0.035989     0.070985    -0.020165
# 2021-02         399        9117     0.035272     0.097949    -0.012833
# 2021-03         628       13705     0.039662     0.081065    -0.015688
# 2021-04         498       10004     0.033180     0.074370    -0.017693
# 2021-05         651       13609     0.048654     0.073113    -0.018885
#
# [110 rows x 20 columns]

# %%
Vars = ["Vader_Compound","Vader_Average","WNSentiment","HVSentiment","LMSentiment"]
for Var in Vars:
    print("\n" + Var + "\n")
    grangerTest(Granger_data_daily[Var], Granger_data_daily['LogReturn'])
# Out:
# Vader_Compound
#
# Optimal number of lags for exog data is 2
# Optimal number of lags for endog data is 2
#
# Granger causality results of indep onto dep
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.3491  , p=0.2475  , df_denom=134, df_num=1
# ssr based chi2 test:   chi2=1.3793  , p=0.2402  , df=1
# likelihood ratio test: chi2=1.3724  , p=0.2414  , df=1
# parameter F test:         F=1.3491  , p=0.2475  , df_denom=134, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.9793  , p=0.1423  , df_denom=131, df_num=2
# ssr based chi2 test:   chi2=4.1097  , p=0.1281  , df=2
# likelihood ratio test: chi2=4.0488  , p=0.1321  , df=2
# parameter F test:         F=1.9793  , p=0.1423  , df_denom=131, df_num=2
#
# Granger causality results of dep onto indep
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.6560  , p=0.4194  , df_denom=134, df_num=1
# ssr based chi2 test:   chi2=0.6707  , p=0.4128  , df=1
# likelihood ratio test: chi2=0.6690  , p=0.4134  , df=1
# parameter F test:         F=0.6560  , p=0.4194  , df_denom=134, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.8218  , p=0.4419  , df_denom=131, df_num=2
# ssr based chi2 test:   chi2=1.7063  , p=0.4261  , df=2
# likelihood ratio test: chi2=1.6957  , p=0.4283  , df=2
# parameter F test:         F=0.8218  , p=0.4419  , df_denom=131, df_num=2
# [0.28332619 0.05906373 0.00390746]
# [ 0.29319144  0.04572626  0.04894878 -0.2166886   0.00380803]
# [0.00104381 0.60077028 0.81123696 0.28675574 0.43093125]
#
# Vader_Average
# C:\Users\Windows\anaconda3\lib\site-packages\statsmodels\tsa\ar_model.py:691: FutureWarning:
# statsmodels.tsa.AR has been deprecated in favor of statsmodels.tsa.AutoReg and
# statsmodels.tsa.SARIMAX.
#
# AutoReg adds the ability to specify exogenous variables, include time trends,
# and add seasonal dummies. The AutoReg API differs from AR since the model is
# treated as immutable, and so the entire specification including the lag
# length must be specified when creating the model. This change is too
# substantial to incorporate into the existing AR api. The function
# ar_select_order performs lag length selection for AutoReg models.
#
# AutoReg only estimates parameters using conditional MLE (OLS). Use SARIMAX to
# estimate ARX and related models using full MLE via the Kalman Filter.
#
# To silence this warning and continue using AR until it is removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.ar_model.AR', FutureWarning)
#
#   warnings.warn(AR_DEPRECATION_WARN, FutureWarning)
# Optimal number of lags for exog data is 2
# Optimal number of lags for endog data is 2
#
# Granger causality results of indep onto dep
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.8342  , p=0.1779  , df_denom=134, df_num=1
# ssr based chi2 test:   chi2=1.8752  , p=0.1709  , df=1
# likelihood ratio test: chi2=1.8625  , p=0.1723  , df=1
# parameter F test:         F=1.8342  , p=0.1779  , df_denom=134, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.2481  , p=0.2904  , df_denom=131, df_num=2
# ssr based chi2 test:   chi2=2.5915  , p=0.2737  , df=2
# likelihood ratio test: chi2=2.5671  , p=0.2771  , df=2
# parameter F test:         F=1.2481  , p=0.2904  , df_denom=131, df_num=2
#
# Granger causality results of dep onto indep
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.9818  , p=0.3235  , df_denom=134, df_num=1
# ssr based chi2 test:   chi2=1.0038  , p=0.3164  , df=1
# likelihood ratio test: chi2=1.0002  , p=0.3173  , df=1
# parameter F test:         F=0.9818  , p=0.3235  , df_denom=134, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.1151  , p=0.3310  , df_denom=131, df_num=2
# ssr based chi2 test:   chi2=2.3152  , p=0.3142  , df=2
# likelihood ratio test: chi2=2.2957  , p=0.3173  , df=2
# parameter F test:         F=1.1151  , p=0.3310  , df_denom=131, df_num=2
# [0.24458325 0.01614784 0.00634652]
# [ 0.25958732 -0.00332059  0.04050373 -0.09718409  0.00634167]
# [0.00353662 0.96976842 0.64149932 0.25944581 0.00468718]
#
# WNSentiment
#
# Optimal number of lags for exog data is 2
# Optimal number of lags for endog data is 2
#
# Granger causality results of indep onto dep
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.1937  , p=0.2766  , df_denom=134, df_num=1
# ssr based chi2 test:   chi2=1.2204  , p=0.2693  , df=1
# likelihood ratio test: chi2=1.2150  , p=0.2703  , df=1
# parameter F test:         F=1.1937  , p=0.2766  , df_denom=134, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.6338  , p=0.5322  , df_denom=131, df_num=2
# ssr based chi2 test:   chi2=1.3160  , p=0.5179  , df=2
# likelihood ratio test: chi2=1.3097  , p=0.5195  , df=2
# parameter F test:         F=0.6338  , p=0.5322  , df_denom=131, df_num=2
#
# Granger causality results of dep onto indep
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.5863  , p=0.4452  , df_denom=134, df_num=1
# ssr based chi2 test:   chi2=0.5995  , p=0.4388  , df=1
# likelihood ratio test: chi2=0.5981  , p=0.4393  , df=1
# parameter F test:         F=0.5863  , p=0.4452  , df_denom=134, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.5098  , p=0.0327  , df_denom=131, df_num=2
# ssr based chi2 test:   chi2=7.2875  , p=0.0262  , df=2
# likelihood ratio test: chi2=7.0990  , p=0.0287  , df=2
# parameter F test:         F=3.5098  , p=0.0327  , df_denom=131, df_num=2
# [0.02574042 0.07400861 0.0134634 ]
# [ 0.03803896  0.05753563 -0.01327207 -0.09045525  0.01345968]
# [6.56530485e-01 5.00147572e-01 7.09051330e-01 1.14908665e-02
#  2.15468737e-10]
#
# HVSentiment
#
# Optimal number of lags for exog data is 2
# Optimal number of lags for endog data is 2
#
# Granger causality results of indep onto dep
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.4940  , p=0.4834  , df_denom=134, df_num=1
# ssr based chi2 test:   chi2=0.5051  , p=0.4773  , df=1
# likelihood ratio test: chi2=0.5042  , p=0.4777  , df=1
# parameter F test:         F=0.4940  , p=0.4834  , df_denom=134, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.8514  , p=0.4292  , df_denom=131, df_num=2
# ssr based chi2 test:   chi2=1.7677  , p=0.4132  , df=2
# likelihood ratio test: chi2=1.7563  , p=0.4155  , df=2
# parameter F test:         F=0.8514  , p=0.4292  , df_denom=131, df_num=2
#
# Granger causality results of dep onto indep
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1585  , p=0.6911  , df_denom=134, df_num=1
# ssr based chi2 test:   chi2=0.1621  , p=0.6872  , df=1
# likelihood ratio test: chi2=0.1620  , p=0.6873  , df=1
# parameter F test:         F=0.1585  , p=0.6911  , df_denom=134, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5077  , p=0.6031  , df_denom=131, df_num=2
# ssr based chi2 test:   chi2=1.0541  , p=0.5903  , df=2
# likelihood ratio test: chi2=1.0501  , p=0.5915  , df=2
# parameter F test:         F=0.5077  , p=0.6031  , df_denom=131, df_num=2
# [0.23017447 0.08851809 0.0227002 ]
# [ 0.23242204  0.08367086 -0.0093493  -0.07640387  0.02273172]
# [8.00955440e-03 3.32231308e-01 9.06394273e-01 3.35451185e-01
#  9.14704455e-08]
#
# LMSentiment
#
# Optimal number of lags for exog data is 3
# Optimal number of lags for endog data is 2
#
# Granger causality results of indep onto dep
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0078  , p=0.9298  , df_denom=134, df_num=1
# ssr based chi2 test:   chi2=0.0080  , p=0.9288  , df=1
# likelihood ratio test: chi2=0.0080  , p=0.9288  , df=1
# parameter F test:         F=0.0078  , p=0.9298  , df_denom=134, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2140  , p=0.8076  , df_denom=131, df_num=2
# ssr based chi2 test:   chi2=0.4444  , p=0.8008  , df=2
# likelihood ratio test: chi2=0.4437  , p=0.8011  , df=2
# parameter F test:         F=0.2140  , p=0.8076  , df_denom=131, df_num=2
#
# Granger causality results of dep onto indep
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.9524  , p=0.1646  , df_denom=134, df_num=1
# ssr based chi2 test:   chi2=1.9961  , p=0.1577  , df=1
# likelihood ratio test: chi2=1.9817  , p=0.1592  , df=1
# parameter F test:         F=1.9524  , p=0.1646  , df_denom=134, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.5807  , p=0.2097  , df_denom=131, df_num=2
# ssr based chi2 test:   chi2=3.2821  , p=0.1938  , df=2
# likelihood ratio test: chi2=3.2431  , p=0.1976  , df=2
# parameter F test:         F=1.5807  , p=0.2097  , df_denom=131, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.5177  , p=0.2131  , df_denom=128, df_num=3
# ssr based chi2 test:   chi2=4.8020  , p=0.1869  , df=3
# likelihood ratio test: chi2=4.7185  , p=0.1936  , df=3
# parameter F test:         F=1.5177  , p=0.2131  , df_denom=128, df_num=3
# [ 0.14919984  0.22120048 -0.02947291]
# [ 0.17291828  0.19519679  0.02735517 -0.05644301 -0.02960492]
# [4.21083297e-02 2.06845669e-02 5.28986753e-01 1.96250946e-01
#  6.79952947e-08]

# %%
Granger_data_monthly[['LogReturn','Vader_Average','Vader_Compound']].plot(legend=True, figsize=(16,9))

# %%
corr = Granger_data_daily[["Vader_Compound","Vader_Average","WNSentiment","HVSentiment","LMSentiment","LogReturn"]].corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow0_col1 {
#             background-color:  #c53334;
#             color:  #f1f1f1;
#         }    #T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow0_col2 {
#             background-color:  #f7ac8e;
#             color:  #000000;
#         }    #T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow0_col3 {
#             background-color:  #f08b6e;
#             color:  #000000;
#         }    #T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow0_col4 {
#             background-color:  #f6a283;
#             color:  #000000;
#         }    #T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow0_col5 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow1_col0 {
#             background-color:  #c53334;
#             color:  #f1f1f1;
#         }    #T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow1_col2 {
#             background-color:  #f39475;
#             color:  #000000;
#         }    #T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow1_col3 {
#             background-color:  #f7a889;
#             color:  #000000;
#         }    #T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow1_col4 {
#             background-color:  #f7b99e;
#             color:  #000000;
#         }    #T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow1_col5 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow2_col0 {
#             background-color:  #f7ac8e;
#             color:  #000000;
#         }    #T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow2_col1 {
#             background-color:  #f39475;
#             color:  #000000;
#         }    #T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow2_col3 {
#             background-color:  #f2cab5;
#             color:  #000000;
#         }    #T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow2_col4 {
#             background-color:  #efcebd;
#             color:  #000000;
#         }    #T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow2_col5 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow3_col0 {
#             background-color:  #f08a6c;
#             color:  #000000;
#         }    #T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow3_col1 {
#             background-color:  #f6a586;
#             color:  #000000;
#         }    #T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow3_col2 {
#             background-color:  #f3c7b1;
#             color:  #000000;
#         }    #T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow3_col4 {
#             background-color:  #f6a385;
#             color:  #000000;
#         }    #T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow3_col5 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow4_col0 {
#             background-color:  #f7a98b;
#             color:  #000000;
#         }    #T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow4_col1 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow4_col2 {
#             background-color:  #ead4c8;
#             color:  #000000;
#         }    #T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow4_col3 {
#             background-color:  #f7ac8e;
#             color:  #000000;
#         }    #T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow4_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow5_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow5_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow5_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow5_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow5_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65ce" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Vader_Compound</th>        <th class="col_heading level0 col1" >Vader_Average</th>        <th class="col_heading level0 col2" >WNSentiment</th>        <th class="col_heading level0 col3" >HVSentiment</th>        <th class="col_heading level0 col4" >LMSentiment</th>        <th class="col_heading level0 col5" >LogReturn</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65celevel0_row0" class="row_heading level0 row0" >Vader_Compound</th>
#                         <td id="T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow0_col1" class="data row0 col1" >0.946405</td>
#                         <td id="T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow0_col2" class="data row0 col2" >0.677773</td>
#                         <td id="T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow0_col3" class="data row0 col3" >0.771421</td>
#                         <td id="T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow0_col4" class="data row0 col4" >0.687455</td>
#                         <td id="T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow0_col5" class="data row0 col5" >-0.080126</td>
#             </tr>
#             <tr>
#                         <th id="T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65celevel0_row1" class="row_heading level0 row1" >Vader_Average</th>
#                         <td id="T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow1_col0" class="data row1 col0" >0.946405</td>
#                         <td id="T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow1_col2" class="data row1 col2" >0.742499</td>
#                         <td id="T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow1_col3" class="data row1 col3" >0.695500</td>
#                         <td id="T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow1_col4" class="data row1 col4" >0.609448</td>
#                         <td id="T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow1_col5" class="data row1 col5" >-0.092176</td>
#             </tr>
#             <tr>
#                         <th id="T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65celevel0_row2" class="row_heading level0 row2" >WNSentiment</th>
#                         <td id="T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow2_col0" class="data row2 col0" >0.677773</td>
#                         <td id="T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow2_col1" class="data row2 col1" >0.742499</td>
#                         <td id="T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow2_col3" class="data row2 col3" >0.581874</td>
#                         <td id="T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow2_col4" class="data row2 col4" >0.520041</td>
#                         <td id="T_5fa7ee02_dc0a_11eb_a915_4ccc6adc65cerow2_col5" class="data row2 col5" >-0.084890</td>
#             </tr>
#             <tr>

# %%
pvals = [] 
for col in ["Vader_Compound","Vader_Average","WNSentiment","HVSentiment","LMSentiment"]:
    pvals.append(scipy.stats.linregress(Granger_data_daily['LogReturn'][1:], Granger_data_daily[col][1:].dropna())[3])
corr_signif = pd.DataFrame(pvals,columns = ['p-value']
                           ,index = ["Vader_Compound","Vader_Average","WNSentiment","HVSentiment","LMSentiment"])
corr_signif
# Out:
#                  p-value
# Vader_Compound  0.363295
# Vader_Average   0.292556
# WNSentiment     0.303349
# HVSentiment     0.504326
# LMSentiment     0.066532

# %%
pvals_mnt = [] 
for col in ['Vader_Compound','Flair_Score','SentimentScoreAdj','Vader_Average']:
    pvals_mnt.append(scipy.stats.linregress(Granger_data_monthly['LogReturn'][1:], Granger_data_monthly[col][1:].dropna())[3])
corr_signif_mnt = pd.DataFrame(pvals_mnt,columns = ['p-value']
                           ,index = ['Vader_Compound','Flair_Score','SentimentScoreAdj','Vader_Average'])
corr_signif_mnt
# Out:
#                     p-value
# Vader_Compound     0.084306
# Flair_Score        0.977764
# SentimentScoreAdj  0.311650
# Vader_Average      0.047369
