# %%
import csv
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt
import pandas_datareader.data as web
import statsmodels.api as sm
from statsmodels.tsa.stattools import grangercausalitytests
from matplotlib import pyplot
import scipy.stats
from statsmodels.tsa.stattools import adfuller
from yahoofinancials import YahooFinancials
from statsmodels.tsa.ar_model import AR
# %matplotlib inline

# %%
fpath = 'facebook_data_FoxNews_comments_sentiment_4dict.tsv'
post_data = pd.read_csv(fpath, sep='\t')
post_data.head()
# Out:
#    ID        PostID             PostDate          CommentID  \
# 0   0  1.016072e+16  2021-05-31 19:06:00  10160717141986336
# 1   1  1.016072e+16  2021-05-31 19:06:00  10160717198346336
# 2   2  1.016072e+16  2021-05-31 19:06:00  10160717252036336
# 3   3  1.016072e+16  2021-05-31 19:06:00  10160717353421336
# 4   4  1.016072e+16  2021-05-31 19:06:00  10160717374471336
#
#            CommentDate                                       CommenterURL  \
# 0  2021-05-31 00:00:00   profile.php?id=100049838682322&fref=nf&rc=p&r...
# 1  2021-05-31 00:00:00      tom.petrick.96?fref=nf&rc=p&refid=52&__tn__=R
# 2  2021-05-31 00:00:00   profile.php?id=100067824624611&fref=nf&rc=p&r...
# 3  2021-05-31 00:00:00          chicks1950?fref=nf&rc=p&refid=52&__tn__=R
# 4  2021-05-31 00:00:00      gaile.jones.35?fref=nf&rc=p&refid=52&__tn__=R
#
#                                          CommentText  WNPositive  WNNegative  \
# 0  Sorry for your loss. He will always be remembe...    0.000000    0.250000
# 1  Rest in Peace, soldier, and may God Bless his ...    0.875000    0.000000
# 2      Son ángeles rresignadion para su familia amen    0.000000    0.000000
# 3  So sorry you lost your son. Prayers to you and...    1.121751    1.036144
# 4  God Bless our fallen soldiers. God Bless Ameri...    0.000000    0.000000
#
#    WNNeutral  ...  HVTokenQnt  HVSentiAvg  LMPositive  LMNegative  LMTokenQnt  \
# 0   3.750000  ...           5   -0.400000           0           2           5
# 1   4.125000  ...           5    0.400000           0           0           5
# 2   3.000000  ...           5    0.200000           0           0           5
# 3   6.842105  ...          11    0.090909           1           2          11
# 4   6.000000  ...           7    0.142857           0           0           7
#
#    LMSentiAvg  Vader_Positive  Vader_Negative  Vader_Neutral  Vader_Compound
# 0   -0.400000           0.126           0.216          0.659         -0.1280
# 1    0.000000           0.634           0.000          0.366          0.9022
# 2    0.000000           0.000           0.000          1.000          0.0000
# 3   -0.090909           0.080           0.214          0.706         -0.4865
# 4    0.000000           0.525           0.103          0.372          0.8478
#
# [5 rows x 25 columns]

# %%
post_data['Vader_Average'] = post_data['Vader_Positive'] - post_data['Vader_Negative']

# %%
bins = np.linspace(-1, 1, 100)
pyplot.hist(post_data['WNSentiAvg'], bins, alpha=0.5, label='WNSentiAvg')
pyplot.hist(post_data['HVSentiAvg'], bins, alpha=0.5, label='HVSentiAvg')
pyplot.hist(post_data['LMSentiAvg'], bins, alpha=0.5, label='LMSentiAvg')
pyplot.hist(post_data['Vader_Compound'], bins, alpha=0.5, label='Vader_Compound')
pyplot.hist(post_data['Vader_Positive'] - post_data['Vader_Negative'], bins, alpha=0.5, label='Vader_Average')
pyplot.legend(loc='upper right')
pyplot.title('Distribution of semantic scores')
pyplot.show()

# %%
# seaborn histogram
sns.distplot((post_data['Vader_Compound'] - post_data['Vader_Compound'].mean())/post_data['Vader_Compound'].std(), hist=False, kde=True, 
             bins=int(180/5), color = 'red',
             hist_kws={'edgecolor':'black'})
sns.distplot((post_data['WNSentiAvg'] - post_data['WNSentiAvg'].mean())/post_data['WNSentiAvg'].std(), hist=False, kde=True, 
             bins=int(180/5), color = 'blue',
             hist_kws={'edgecolor':'black'})
sns.distplot((post_data['LMSentiAvg'] - post_data['LMSentiAvg'].mean())/post_data['LMSentiAvg'].std(), hist=False, kde=True, 
             bins=int(180/5), color = 'green',
             hist_kws={'edgecolor':'black'})
sns.distplot((post_data['HVSentiAvg'] - post_data['HVSentiAvg'].mean())/post_data['HVSentiAvg'].std(), hist=False, kde=True, 
             bins=int(180/5), color = 'orange',
             hist_kws={'edgecolor':'black'})
sns.distplot((post_data['Vader_Average'] - post_data['Vader_Average'].mean())/post_data['Vader_Average'].std(), hist=False, kde=True, 
             bins=int(180/5), color = 'purple',
             hist_kws={'edgecolor':'black'})
# Add labels
plt.title('Distribution of Sentiment Score')
plt.xlabel('Score')
plt.ylabel('Posts')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     450     try:
# --> 451         bw = float(bw)
#     452     except:
#
# ValueError: could not convert string to float: 'scott'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-a2f4ccab2252> in <module>
#       8 sns.distplot((post_data['LMSentiAvg'] - post_data['LMSentiAvg'].mean())/post_data['LMSentiAvg'].std(), hist=False, kde=True,
#       9              bins=int(180/5), color = 'green',
# ---> 10              hist_kws={'edgecolor':'black'})
#      11 sns.distplot((post_data['HVSentiAvg'] - post_data['HVSentiAvg'].mean())/post_data['HVSentiAvg'].std(), hist=False, kde=True,
#      12              bins=int(180/5), color = 'orange',
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     231     if kde:
#     232         kde_color = kde_kws.pop("color", color)
# --> 233         kdeplot(a, vertical=vertical, ax=ax, color=kde_color, **kde_kws)
#     234         if kde_color != color:
#     235             kde_kws["color"] = kde_color
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     703         ax = _univariate_kdeplot(data, shade, vertical, kernel, bw,
#     704                                  gridsize, cut, clip, legend, ax,
# --> 705                                  cumulative=cumulative, **kwargs)
#     706
#     707     return ax
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in _univariate_kdeplot(data, shade, vertical, kernel, bw, gridsize, cut, clip, legend, ax, cumulative, **kwargs)
#     293         x, y = _statsmodels_univariate_kde(data, kernel, bw,
#     294                                            gridsize, cut, clip,
# --> 295                                            cumulative=cumulative)
#     296     else:
#     297         # Fall back to scipy if missing statsmodels
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in _statsmodels_univariate_kde(data, kernel, bw, gridsize, cut, clip, cumulative)
#     365     fft = kernel == "gau"
#     366     kde = smnp.KDEUnivariate(data)
# --> 367     kde.fit(kernel, bw, fft, gridsize=gridsize, cut=cut, clip=clip)
#     368     if cumulative:
#     369         grid, y = kde.support, kde.cdf
#
# ~\anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in fit(self, kernel, bw, fft, weights, gridsize, adjust, cut, clip)
#     138             density, grid, bw = kdensityfft(endog, kernel=kernel, bw=bw,
#     139                     adjust=adjust, weights=weights, gridsize=gridsize,
# --> 140                     clip=clip, cut=cut)
#     141         else:
#     142             density, grid, bw = kdensity(endog, kernel=kernel, bw=bw,
#
# ~\anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     451         bw = float(bw)
#     452     except:
# --> 453         bw = bandwidths.select_bandwidth(X, bw, kern) # will cross-val fit this pattern?
#     454     bw *= adjust
#     455
#
# ~\anaconda3\lib\site-packages\statsmodels\nonparametric\bandwidths.py in select_bandwidth(x, bw, kernel)
#     172         # eventually this can fall back on another selection criterion.
#     173         err = "Selected KDE bandwidth is 0. Cannot estiamte density."
# --> 174         raise RuntimeError(err)
#     175     else:
#     176         return bandwidth
#
# RuntimeError: Selected KDE bandwidth is 0. Cannot estiamte density.

# %%
post_data[['WNSentiAvg','HVSentiAvg','LMSentiAvg','Vader_Compound','Vader_Average']].describe()
# Out:
#           WNSentiAvg     HVSentiAvg     LMSentiAvg  Vader_Compound  \
# count  305713.000000  305713.000000  305713.000000   305713.000000
# mean        0.027981       0.007817      -0.027696        0.031826
# std         0.174430       0.346595       0.169648        0.500568
# min        -1.000000      -1.000000      -1.000000       -1.000000
# 25%        -0.017857      -0.111111       0.000000       -0.340000
# 50%         0.000000       0.000000       0.000000        0.000000
# 75%         0.062500       0.142857       0.000000        0.440400
# max         1.000000       1.000000       1.000000        1.000000
#
#        Vader_Average
# count  305713.000000
# mean        0.038621
# std         0.317384
# min        -1.000000
# 25%        -0.088000
# 50%         0.000000
# 75%         0.171000
# max         1.000000

# %%
post_data['PostDate'] = pd.to_datetime(post_data['PostDate'], errors='coerce')

post_data['DateMonth'] = post_data['PostDate'].dt.strftime('%Y-%m')
post_data['DateDay'] = post_data['PostDate'].dt.strftime('%Y-%m-%d')

# %%
post_data['DateMonth'].head()
# Out:
# 0    2021-05
# 1    2021-05
# 2    2021-05
# 3    2021-05
# 4    2021-05
# Name: DateMonth, dtype: object

# %%
post_data.columns
# Out:
# Index(['ID', 'PostID', 'PostDate', 'CommentID', 'CommentDate', 'CommenterURL',
#        'CommentText', 'WNPositive', 'WNNegative', 'WNNeutral', 'WNSentiment',
#        'WNTokenQnt', 'WNSentiAvg', 'HVPositive', 'HVNegative', 'HVTokenQnt',
#        'HVSentiAvg', 'LMPositive', 'LMNegative', 'LMTokenQnt', 'LMSentiAvg',
#        'Vader_Positive', 'Vader_Negative', 'Vader_Neutral', 'Vader_Compound',
#        'Vader_Average', 'DateMonth', 'DateDay'],
#       dtype='object')

# %%
Monthly_Data = post_data.groupby('DateMonth').agg({'WNSentiAvg': 'sum'
                                                         ,'WNTokenQnt':'count'
                                                        ,'Vader_Compound':'mean'
                                                        ,'Vader_Average': 'mean'
                                                        ,'HVPositive':'sum'
                                                        ,'HVNegative':'sum'
                                                        ,'HVTokenQnt':'sum'
                                                        ,'LMPositive':'sum'
                                                        ,'LMNegative':'sum'
                                                        ,'LMTokenQnt':'sum'
                                                       })

# %%
DailyData = post_data.groupby('DateDay').agg({'WNSentiAvg': 'sum'
                                                        ,'WNTokenQnt':'count'
                                                        ,'Vader_Compound':'mean'
                                                        ,'Vader_Average': 'mean'
                                                        ,'HVPositive':'sum'
                                                        ,'HVNegative':'sum'
                                                        ,'HVTokenQnt':'sum'
                                                        ,'LMPositive':'sum'
                                                        ,'LMNegative':'sum'
                                                        ,'LMTokenQnt':'sum'
                                                        })

# %%
DailyData['WNSentiment'] =  DailyData['WNSentiAvg']/ DailyData['WNTokenQnt']
DailyData['HVSentiment'] = (DailyData['HVPositive'] - DailyData['HVNegative'])/DailyData['HVTokenQnt']
DailyData['LMSentiment'] = (DailyData['LMPositive'] - DailyData['LMNegative'])/DailyData['LMTokenQnt']

Monthly_Data['WNSentiment'] =  Monthly_Data['WNSentiAvg']/ Monthly_Data['WNTokenQnt']
Monthly_Data['HVSentiment'] = (Monthly_Data['HVPositive'] - Monthly_Data['HVNegative'])/Monthly_Data['HVTokenQnt']
Monthly_Data['LMSentiment'] = (Monthly_Data['LMPositive'] - Monthly_Data['LMNegative'])/Monthly_Data['LMTokenQnt']

# %%
print('Results of Dickey-Fuller Test:')
dftest = adfuller(DailyData['WNSentiment'].dropna(), autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
for i in range(len(dfoutput)):
    dfoutput[i] = round(dfoutput[i],4)
print(dfoutput)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -10.7008
# p-value                           0.0000
# #Lags Used                        5.0000
# Number of Observations Used    1325.0000
# Critical Value (1%)              -3.4353
# Critical Value (5%)              -2.8637
# Critical Value (10%)             -2.5679
# dtype: float64

# %%
print('Results of Dickey-Fuller Test:')
dftest = adfuller(DailyData['HVSentiment'].dropna(), autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
for i in range(len(dfoutput)):
    dfoutput[i] = round(dfoutput[i],4)
print(dfoutput)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   -9.3448
# p-value                           0.0000
# #Lags Used                        9.0000
# Number of Observations Used    1321.0000
# Critical Value (1%)              -3.4353
# Critical Value (5%)              -2.8637
# Critical Value (10%)             -2.5679
# dtype: float64

# %%
for i in range(len(dfoutput)):
    dfoutput[i] = round(dfoutput[i],4)
print(dfoutput)
print('Results of Dickey-Fuller Test:')
dftest = adfuller(DailyData['LMSentiment'].dropna(), autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
# Out:
# Test Statistic                   -9.3448
# p-value                           0.0000
# #Lags Used                        9.0000
# Number of Observations Used    1321.0000
# Critical Value (1%)              -3.4353
# Critical Value (5%)              -2.8637
# Critical Value (10%)             -2.5679
# dtype: float64
# Results of Dickey-Fuller Test:

# %%
for i in range(len(dfoutput)):
    dfoutput[i] = round(dfoutput[i],4)
print(dfoutput)
print('Results of Dickey-Fuller Test:')
dftest = adfuller(DailyData['Vader_Compound'].dropna(), autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
# Out:
# Test Statistic                  -10.0267
# p-value                           0.0000
# #Lags Used                        8.0000
# Number of Observations Used    1322.0000
# Critical Value (1%)              -3.4353
# Critical Value (5%)              -2.8637
# Critical Value (10%)             -2.5679
# dtype: float64
# Results of Dickey-Fuller Test:

# %%
DailyData.head()
# Out:
#             WNSentiAvg  WNTokenQnt  Vader_Compound  Vader_Average  HVPositive  \
# DateDay
# 2012-04-25   -0.505128          51       -0.112894      -0.080176         134
# 2012-04-26   -0.590616          49        0.039663       0.038837         175
# 2012-04-27    0.526024          25        0.164220       0.077280          86
# 2012-04-28    3.689543          84        0.033498       0.042512         136
# 2012-04-29   -1.008734          55       -0.112620      -0.067164         407
#
#             HVNegative  HVTokenQnt  LMPositive  LMNegative  LMTokenQnt  \
# DateDay
# 2012-04-25         139         833          12          61         833
# 2012-04-26         132        1146          16          49        1146
# 2012-04-27          77         639           9          24         639
# 2012-04-28         132        1046          12          60        1046
# 2012-04-29         355        2709          57         197        2709
#
#             WNSentiment  HVSentiment  LMSentiment
# DateDay
# 2012-04-25    -0.009904    -0.006002    -0.058824
# 2012-04-26    -0.012053     0.037522    -0.028796
# 2012-04-27     0.021041     0.014085    -0.023474
# 2012-04-28     0.043923     0.003824    -0.045889
# 2012-04-29    -0.018341     0.019195    -0.051680

# %%
Monthly_Data[['Vader_Compound','WNSentiment','HVSentiment','LMSentiment','Vader_Average']].plot(legend=True, figsize=(16,9))

# %% [markdown]
# ## Download S&P from Yahoo

# %%
#SnP_daily = web.get_data_yahoo('^GSPC','10/01/2010','05/01/2021',interval='d')
#SnP_monthly = web.get_data_yahoo('^GSPC','10/01/2010','05/01/2021',interval='m')
yahoo_financials = YahooFinancials(['^GSPC']).get_historical_price_data('2019-01-01','2021-05-31','daily')
SnP_daily =pd.DataFrame(yahoo_financials["^GSPC"]["prices"])
SnP_daily.index = SnP_daily['formatted_date']
SnP_daily['LogReturn'] = np.log(SnP_daily['adjclose']/SnP_daily['adjclose'].shift(1))

yahoo_financials_m = YahooFinancials(['^GSPC']).get_historical_price_data('2019-01-01','2021-05-31','monthly')
SnP_monthly =pd.DataFrame(yahoo_financials_m["^GSPC"]["prices"])
SnP_monthly.index = SnP_monthly['formatted_date']
SnP_monthly['LogReturn'] = np.log(SnP_monthly['adjclose']/SnP_monthly['adjclose'].shift(1))

# %%
#SnP_daily['LogReturn'] = np.log(SnP_daily['Adj Close']/SnP_daily['Adj Close'].shift(1))

# %%
#SnP_monthly.index = SnP_monthly.index.strftime('%Y-%m')

# %%
#SnP_monthly['LogReturn'] = np.log(SnP_monthly['Adj Close']/SnP_monthly['Adj Close'].shift(1))

# %% [markdown]
# ## Granger test

# %%
Granger_data_daily = pd.merge(SnP_daily,DailyData, how= 'inner', left_index=True, right_index=True)

# %%
def grangerTest(exog, endog):
    MAX_LAG = 30
    ARaic = AR(exog.tolist()).fit(maxlag=MAX_LAG, ic="aic")
    ARbic = AR(exog.tolist()).fit(maxlag=MAX_LAG, ic="bic")
    # select the fewer number of parameters between both criteria.
    numExog = len(ARaic.params) if len(ARaic.params) < len(ARbic.params) else len(ARbic.params)

    print ("Optimal number of lags for exog data is " + str(numExog))

    ARaic = AR(endog.tolist()).fit(maxlag=MAX_LAG, ic="aic")
    ARbic = AR(endog.tolist()).fit(maxlag=MAX_LAG, ic="bic")
    # select the fewer number of parameters between both criteria.
    numEndog = len(ARaic.params) if len(ARaic.params) < len(ARbic.params) else len(ARbic.params)

    print ("Optimal number of lags for endog data is " + str(numEndog))

    # now that I know the optimal number of parameters, I can call the
    # granger causality function of statsmodels.
    data = pd.concat([endog, exog], axis=1)
    print ("\nGranger causality results of indep onto dep")
    results = grangercausalitytests(data, maxlag=numEndog)

    data = pd.concat([exog, endog], axis=1)
    print ("\nGranger causality results of dep onto indep")
    results = grangercausalitytests(data, maxlag=numExog)
    regr = results[2][1]
    print (regr[0].params)
    print (regr[1].params)
    print (regr[1].pvalues)

# %%
#Granger_data_monthly = pd.merge(SnP_monthly,Monthly_Data, how= 'inner', left_index=True, right_index=True)

# %%
#Granger_data['SS_LogReturn'] = np.log((Granger_data['SentimentScoreAdj']+1)/(Granger_data['SentimentScoreAdj']+1).shift(1))

# %%
#Granger_data_monthly

# %%
Vars = ["Vader_Compound","Vader_Average","WNSentiment","HVSentiment","LMSentiment"]
for Var in Vars:
    print("\n" + Var + "\n")
    grangerTest(Granger_data_daily[Var], Granger_data_daily['LogReturn'])
# Out:
# Vader_Compound
#
# Optimal number of lags for exog data is 2
# Optimal number of lags for endog data is 9
#
# Granger causality results of indep onto dep
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.7147  , p=0.3986  , df_denom=294, df_num=1
# ssr based chi2 test:   chi2=0.7220  , p=0.3955  , df=1
# likelihood ratio test: chi2=0.7212  , p=0.3958  , df=1
# parameter F test:         F=0.7147  , p=0.3986  , df_denom=294, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5665  , p=0.5681  , df_denom=291, df_num=2
# ssr based chi2 test:   chi2=1.1525  , p=0.5620  , df=2
# likelihood ratio test: chi2=1.1503  , p=0.5626  , df=2
# parameter F test:         F=0.5665  , p=0.5681  , df_denom=291, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.5980  , p=0.6168  , df_denom=288, df_num=3
# ssr based chi2 test:   chi2=1.8376  , p=0.6068  , df=3
# likelihood ratio test: chi2=1.8319  , p=0.6080  , df=3
# parameter F test:         F=0.5980  , p=0.6168  , df_denom=288, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.6680  , p=0.6147  , df_denom=285, df_num=4
# ssr based chi2 test:   chi2=2.7562  , p=0.5994  , df=4
# likelihood ratio test: chi2=2.7433  , p=0.6017  , df=4
# parameter F test:         F=0.6680  , p=0.6147  , df_denom=285, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.0486  , p=0.3893  , df_denom=282, df_num=5
# ssr based chi2 test:   chi2=5.4477  , p=0.3637  , df=5
# likelihood ratio test: chi2=5.3977  , p=0.3693  , df=5
# parameter F test:         F=1.0486  , p=0.3893  , df_denom=282, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.0619  , p=0.3857  , df_denom=279, df_num=6
# C:\Users\Windows\anaconda3\lib\site-packages\statsmodels\tsa\ar_model.py:691: FutureWarning:
# statsmodels.tsa.AR has been deprecated in favor of statsmodels.tsa.AutoReg and
# statsmodels.tsa.SARIMAX.
#
# AutoReg adds the ability to specify exogenous variables, include time trends,
# and add seasonal dummies. The AutoReg API differs from AR since the model is
# treated as immutable, and so the entire specification including the lag
# length must be specified when creating the model. This change is too
# substantial to incorporate into the existing AR api. The function
# ar_select_order performs lag length selection for AutoReg models.
#
# AutoReg only estimates parameters using conditional MLE (OLS). Use SARIMAX to
# estimate ARX and related models using full MLE via the Kalman Filter.
#
# To silence this warning and continue using AR until it is removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.ar_model.AR', FutureWarning)
#
#   warnings.warn(AR_DEPRECATION_WARN, FutureWarning)
# ssr based chi2 test:   chi2=6.6684  , p=0.3526  , df=6
# likelihood ratio test: chi2=6.5934  , p=0.3601  , df=6
# parameter F test:         F=1.0619  , p=0.3857  , df_denom=279, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.0077  , p=0.4259  , df_denom=276, df_num=7
# ssr based chi2 test:   chi2=7.4375  , p=0.3848  , df=7
# likelihood ratio test: chi2=7.3441  , p=0.3940  , df=7
# parameter F test:         F=1.0077  , p=0.4259  , df_denom=276, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.9305  , p=0.4916  , df_denom=273, df_num=8
# ssr based chi2 test:   chi2=7.9079  , p=0.4425  , df=8
# likelihood ratio test: chi2=7.8020  , p=0.4530  , df=8
# parameter F test:         F=0.9305  , p=0.4916  , df_denom=273, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.8139  , p=0.6038  , df_denom=270, df_num=9
# ssr based chi2 test:   chi2=7.8407  , p=0.5503  , df=9
# likelihood ratio test: chi2=7.7362  , p=0.5609  , df=9
# parameter F test:         F=0.8139  , p=0.6038  , df_denom=270, df_num=9
#
# Granger causality results of dep onto indep
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1910  , p=0.6624  , df_denom=294, df_num=1
# ssr based chi2 test:   chi2=0.1929  , p=0.6605  , df=1
# likelihood ratio test: chi2=0.1928  , p=0.6606  , df=1
# parameter F test:         F=0.1910  , p=0.6624  , df_denom=294, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1676  , p=0.8458  , df_denom=291, df_num=2
# ssr based chi2 test:   chi2=0.3410  , p=0.8432  , df=2
# likelihood ratio test: chi2=0.3408  , p=0.8433  , df=2
# parameter F test:         F=0.1676  , p=0.8458  , df_denom=291, df_num=2
# [0.27915695 0.07301015 0.01538562]
# [0.27752229 0.07149677 0.11469033 0.09916524 0.01543341]
# [3.18434553e-06 2.22608057e-01 6.12558006e-01 6.61313856e-01
#  4.20699066e-04]
#
# Vader_Average
#
# Optimal number of lags for exog data is 2
# Optimal number of lags for endog data is 9
#
# Granger causality results of indep onto dep
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.5329  , p=0.4660  , df_denom=294, df_num=1
# ssr based chi2 test:   chi2=0.5383  , p=0.4631  , df=1
# likelihood ratio test: chi2=0.5378  , p=0.4633  , df=1
# parameter F test:         F=0.5329  , p=0.4660  , df_denom=294, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3649  , p=0.6946  , df_denom=291, df_num=2
# ssr based chi2 test:   chi2=0.7423  , p=0.6899  , df=2
# likelihood ratio test: chi2=0.7414  , p=0.6902  , df=2
# parameter F test:         F=0.3649  , p=0.6946  , df_denom=291, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.6855  , p=0.5615  , df_denom=288, df_num=3
# ssr based chi2 test:   chi2=2.1065  , p=0.5506  , df=3
# likelihood ratio test: chi2=2.0990  , p=0.5521  , df=3
# parameter F test:         F=0.6855  , p=0.5615  , df_denom=288, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7990  , p=0.5266  , df_denom=285, df_num=4
# ssr based chi2 test:   chi2=3.2971  , p=0.5094  , df=4
# likelihood ratio test: chi2=3.2787  , p=0.5123  , df=4
# parameter F test:         F=0.7990  , p=0.5266  , df_denom=285, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.4881  , p=0.1937  , df_denom=282, df_num=5
# ssr based chi2 test:   chi2=7.7306  , p=0.1717  , df=5
# likelihood ratio test: chi2=7.6304  , p=0.1778  , df=5
# parameter F test:         F=1.4881  , p=0.1937  , df_denom=282, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.3568  , p=0.2322  , df_denom=279, df_num=6
# ssr based chi2 test:   chi2=8.5204  , p=0.2024  , df=6
# likelihood ratio test: chi2=8.3985  , p=0.2103  , df=6
# parameter F test:         F=1.3568  , p=0.2322  , df_denom=279, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.3131  , p=0.2439  , df_denom=276, df_num=7
# ssr based chi2 test:   chi2=9.6915  , p=0.2067  , df=7
# likelihood ratio test: chi2=9.5336  , p=0.2166  , df=7
# parameter F test:         F=1.3131  , p=0.2439  , df_denom=276, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.3009  , p=0.2429  , df_denom=273, df_num=8
# ssr based chi2 test:   chi2=11.0556 , p=0.1986  , df=8
# likelihood ratio test: chi2=10.8501 , p=0.2103  , df=8
# parameter F test:         F=1.3009  , p=0.2429  , df_denom=273, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.1691  , p=0.3150  , df_denom=270, df_num=9
# ssr based chi2 test:   chi2=11.2619 , p=0.2582  , df=9
# likelihood ratio test: chi2=11.0480 , p=0.2724  , df=9
# parameter F test:         F=1.1691  , p=0.3150  , df_denom=270, df_num=9
#
# Granger causality results of dep onto indep
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0024  , p=0.9609  , df_denom=294, df_num=1
# ssr based chi2 test:   chi2=0.0024  , p=0.9606  , df=1
# likelihood ratio test: chi2=0.0024  , p=0.9606  , df=1
# parameter F test:         F=0.0024  , p=0.9609  , df_denom=294, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.0914  , p=0.9127  , df_denom=291, df_num=2
# ssr based chi2 test:   chi2=0.1858  , p=0.9113  , df=2
# likelihood ratio test: chi2=0.1858  , p=0.9113  , df=2
# parameter F test:         F=0.0914  , p=0.9127  , df_denom=291, df_num=2
# [0.27844513 0.11137624 0.01685632]
# [0.27850318 0.11082178 0.00477985 0.06548478 0.01685972]
# [2.74812329e-06 5.84573052e-02 9.76144469e-01 6.81805994e-01
#  1.20926020e-06]
#
# WNSentiment
#
# Optimal number of lags for exog data is 2
# Optimal number of lags for endog data is 9
#
# Granger causality results of indep onto dep
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.5199  , p=0.2186  , df_denom=294, df_num=1
# ssr based chi2 test:   chi2=1.5355  , p=0.2153  , df=1
# likelihood ratio test: chi2=1.5315  , p=0.2159  , df=1
# parameter F test:         F=1.5199  , p=0.2186  , df_denom=294, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5575  , p=0.5733  , df_denom=291, df_num=2
# ssr based chi2 test:   chi2=1.1341  , p=0.5672  , df=2
# likelihood ratio test: chi2=1.1320  , p=0.5678  , df=2
# parameter F test:         F=0.5575  , p=0.5733  , df_denom=291, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2827  , p=0.8379  , df_denom=288, df_num=3
# ssr based chi2 test:   chi2=0.8687  , p=0.8330  , df=3
# likelihood ratio test: chi2=0.8674  , p=0.8333  , df=3
# parameter F test:         F=0.2827  , p=0.8379  , df_denom=288, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.2722  , p=0.8958  , df_denom=285, df_num=4
# ssr based chi2 test:   chi2=1.1230  , p=0.8906  , df=4
# likelihood ratio test: chi2=1.1209  , p=0.8909  , df=4
# parameter F test:         F=0.2722  , p=0.8958  , df_denom=285, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.1093  , p=0.9902  , df_denom=282, df_num=5
# ssr based chi2 test:   chi2=0.5676  , p=0.9894  , df=5
# likelihood ratio test: chi2=0.5670  , p=0.9895  , df=5
# parameter F test:         F=0.1093  , p=0.9902  , df_denom=282, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.1417  , p=0.9905  , df_denom=279, df_num=6
# ssr based chi2 test:   chi2=0.8898  , p=0.9894  , df=6
# likelihood ratio test: chi2=0.8885  , p=0.9895  , df=6
# parameter F test:         F=0.1417  , p=0.9905  , df_denom=279, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.1206  , p=0.9969  , df_denom=276, df_num=7
# ssr based chi2 test:   chi2=0.8900  , p=0.9964  , df=7
# likelihood ratio test: chi2=0.8886  , p=0.9964  , df=7
# parameter F test:         F=0.1206  , p=0.9969  , df_denom=276, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.1868  , p=0.9926  , df_denom=273, df_num=8
# ssr based chi2 test:   chi2=1.5871  , p=0.9912  , df=8
# likelihood ratio test: chi2=1.5828  , p=0.9912  , df=8
# parameter F test:         F=0.1868  , p=0.9926  , df_denom=273, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.2806  , p=0.9796  , df_denom=270, df_num=9
# ssr based chi2 test:   chi2=2.7028  , p=0.9749  , df=9
# likelihood ratio test: chi2=2.6902  , p=0.9753  , df=9
# parameter F test:         F=0.2806  , p=0.9796  , df_denom=270, df_num=9
#
# Granger causality results of dep onto indep
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0393  , p=0.8431  , df_denom=294, df_num=1
# ssr based chi2 test:   chi2=0.0397  , p=0.8421  , df=1
# likelihood ratio test: chi2=0.0397  , p=0.8421  , df=1
# parameter F test:         F=0.0393  , p=0.8431  , df_denom=294, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.4146  , p=0.6610  , df_denom=291, df_num=2
# ssr based chi2 test:   chi2=0.8434  , p=0.6559  , df=2
# likelihood ratio test: chi2=0.8422  , p=0.6563  , df=2
# parameter F test:         F=0.4146  , p=0.6610  , df_denom=291, df_num=2
# [0.3132493  0.1446892  0.02886117]
# [0.31273105 0.13869217 0.04760581 0.25856361 0.02916335]
# [1.67714058e-07 1.79926360e-02 8.69124980e-01 3.70814376e-01
#  3.28651018e-06]
#
# HVSentiment
#
# Optimal number of lags for exog data is 2
# Optimal number of lags for endog data is 9
#
# Granger causality results of indep onto dep
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.8625  , p=0.3538  , df_denom=294, df_num=1
# ssr based chi2 test:   chi2=0.8713  , p=0.3506  , df=1
# likelihood ratio test: chi2=0.8701  , p=0.3509  , df=1
# parameter F test:         F=0.8625  , p=0.3538  , df_denom=294, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5085  , p=0.6019  , df_denom=291, df_num=2
# ssr based chi2 test:   chi2=1.0346  , p=0.5961  , df=2
# likelihood ratio test: chi2=1.0328  , p=0.5967  , df=2
# parameter F test:         F=0.5085  , p=0.6019  , df_denom=291, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3590  , p=0.7827  , df_denom=288, df_num=3
# ssr based chi2 test:   chi2=1.1031  , p=0.7763  , df=3
# likelihood ratio test: chi2=1.1010  , p=0.7768  , df=3
# parameter F test:         F=0.3590  , p=0.7827  , df_denom=288, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.3228  , p=0.8626  , df_denom=285, df_num=4
# ssr based chi2 test:   chi2=1.3320  , p=0.8559  , df=4
# likelihood ratio test: chi2=1.3290  , p=0.8564  , df=4
# parameter F test:         F=0.3228  , p=0.8626  , df_denom=285, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.5712  , p=0.7221  , df_denom=282, df_num=5
# ssr based chi2 test:   chi2=2.9673  , p=0.7050  , df=5
# likelihood ratio test: chi2=2.9523  , p=0.7073  , df=5
# parameter F test:         F=0.5712  , p=0.7221  , df_denom=282, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.4477  , p=0.8464  , df_denom=279, df_num=6
# ssr based chi2 test:   chi2=2.8111  , p=0.8322  , df=6
# likelihood ratio test: chi2=2.7977  , p=0.8338  , df=6
# parameter F test:         F=0.4477  , p=0.8464  , df_denom=279, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.4392  , p=0.8771  , df_denom=276, df_num=7
# ssr based chi2 test:   chi2=3.2412  , p=0.8618  , df=7
# likelihood ratio test: chi2=3.2233  , p=0.8636  , df=7
# parameter F test:         F=0.4392  , p=0.8771  , df_denom=276, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.3928  , p=0.9240  , df_denom=273, df_num=8
# ssr based chi2 test:   chi2=3.3378  , p=0.9114  , df=8
# likelihood ratio test: chi2=3.3187  , p=0.9128  , df=8
# parameter F test:         F=0.3928  , p=0.9240  , df_denom=273, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.3968  , p=0.9361  , df_denom=270, df_num=9
# ssr based chi2 test:   chi2=3.8228  , p=0.9227  , df=9
# likelihood ratio test: chi2=3.7977  , p=0.9242  , df=9
# parameter F test:         F=0.3968  , p=0.9361  , df_denom=270, df_num=9
#
# Granger causality results of dep onto indep
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3487  , p=0.5553  , df_denom=294, df_num=1
# ssr based chi2 test:   chi2=0.3523  , p=0.5528  , df=1
# likelihood ratio test: chi2=0.3521  , p=0.5529  , df=1
# parameter F test:         F=0.3487  , p=0.5553  , df_denom=294, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1562  , p=0.8555  , df_denom=291, df_num=2
# ssr based chi2 test:   chi2=0.3177  , p=0.8531  , df=2
# likelihood ratio test: chi2=0.3175  , p=0.8532  , df=2
# parameter F test:         F=0.1562  , p=0.8555  , df_denom=291, df_num=2
# [0.14374493 0.01541356 0.00660813]
# [ 0.1442209   0.01385989  0.04949542 -0.01222636  0.00661254]
# [1.43320898e-02 8.13336926e-01 6.36941628e-01 9.07052678e-01
#  7.62977196e-04]
#
# LMSentiment
#
# Optimal number of lags for exog data is 2
# Optimal number of lags for endog data is 9
#
# Granger causality results of indep onto dep
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.4962  , p=0.2222  , df_denom=294, df_num=1
# ssr based chi2 test:   chi2=1.5115  , p=0.2189  , df=1
# likelihood ratio test: chi2=1.5077  , p=0.2195  , df=1
# parameter F test:         F=1.4962  , p=0.2222  , df_denom=294, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.5405  , p=0.2160  , df_denom=291, df_num=2
# ssr based chi2 test:   chi2=3.1339  , p=0.2087  , df=2
# likelihood ratio test: chi2=3.1175  , p=0.2104  , df=2
# parameter F test:         F=1.5405  , p=0.2160  , df_denom=291, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.8853  , p=0.4491  , df_denom=288, df_num=3
# ssr based chi2 test:   chi2=2.7204  , p=0.4368  , df=3
# likelihood ratio test: chi2=2.7080  , p=0.4389  , df=3
# parameter F test:         F=0.8853  , p=0.4491  , df_denom=288, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7623  , p=0.5505  , df_denom=285, df_num=4
# ssr based chi2 test:   chi2=3.1455  , p=0.5338  , df=4
# likelihood ratio test: chi2=3.1288  , p=0.5365  , df=4
# parameter F test:         F=0.7623  , p=0.5505  , df_denom=285, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.4511  , p=0.8124  , df_denom=282, df_num=5
# ssr based chi2 test:   chi2=2.3434  , p=0.7999  , df=5
# likelihood ratio test: chi2=2.3340  , p=0.8013  , df=5
# parameter F test:         F=0.4511  , p=0.8124  , df_denom=282, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.3957  , p=0.8815  , df_denom=279, df_num=6
# ssr based chi2 test:   chi2=2.4850  , p=0.8701  , df=6
# likelihood ratio test: chi2=2.4745  , p=0.8713  , df=6
# parameter F test:         F=0.3957  , p=0.8815  , df_denom=279, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.4382  , p=0.8777  , df_denom=276, df_num=7
# ssr based chi2 test:   chi2=3.2341  , p=0.8625  , df=7
# likelihood ratio test: chi2=3.2162  , p=0.8643  , df=7
# parameter F test:         F=0.4382  , p=0.8777  , df_denom=276, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.3492  , p=0.9457  , df_denom=273, df_num=8
# ssr based chi2 test:   chi2=2.9679  , p=0.9364  , df=8
# likelihood ratio test: chi2=2.9528  , p=0.9373  , df=8
# parameter F test:         F=0.3492  , p=0.9457  , df_denom=273, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.3313  , p=0.9642  , df_denom=270, df_num=9
# ssr based chi2 test:   chi2=3.1915  , p=0.9562  , df=9
# likelihood ratio test: chi2=3.1740  , p=0.9570  , df=9
# parameter F test:         F=0.3313  , p=0.9642  , df_denom=270, df_num=9
#
# Granger causality results of dep onto indep
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1266  , p=0.7222  , df_denom=294, df_num=1
# ssr based chi2 test:   chi2=0.1279  , p=0.7206  , df=1
# likelihood ratio test: chi2=0.1279  , p=0.7206  , df=1
# parameter F test:         F=0.1266  , p=0.7222  , df_denom=294, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5336  , p=0.5871  , df_denom=291, df_num=2
# ssr based chi2 test:   chi2=1.0855  , p=0.5811  , df=2
# likelihood ratio test: chi2=1.0836  , p=0.5817  , df=2
# parameter F test:         F=0.5336  , p=0.5871  , df_denom=291, df_num=2
# [ 0.35238045  0.04357958 -0.02179494]
# [ 0.34962973  0.03983853  0.04800291  0.07431094 -0.02204559]
# [6.71932056e-09 4.96671514e-01 5.25412986e-01 3.25388892e-01
#  1.61674214e-14]

# %%
Granger_data_monthly[['LogReturn','Vader_Average','Vader_Compound']].plot(legend=True, figsize=(16,9))

# %%
corr = Granger_data_daily[["Vader_Compound","Vader_Average","WNSentiment","HVSentiment","LMSentiment","LogReturn"]].corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow0_col1 {
#             background-color:  #cc403a;
#             color:  #f1f1f1;
#         }    #T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow0_col2 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow0_col3 {
#             background-color:  #f7b89c;
#             color:  #000000;
#         }    #T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow0_col4 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow0_col5 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow1_col0 {
#             background-color:  #cc403a;
#             color:  #f1f1f1;
#         }    #T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow1_col2 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow1_col3 {
#             background-color:  #efcebd;
#             color:  #000000;
#         }    #T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow1_col4 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow1_col5 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow2_col0 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow2_col1 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow2_col3 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow2_col4 {
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }    #T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow2_col5 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow3_col0 {
#             background-color:  #f7bca1;
#             color:  #000000;
#         }    #T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow3_col1 {
#             background-color:  #eed0c0;
#             color:  #000000;
#         }    #T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow3_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow3_col4 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }    #T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow3_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow4_col0 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow4_col1 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow4_col2 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow4_col3 {
#             background-color:  #edd1c2;
#             color:  #000000;
#         }    #T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow4_col5 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow5_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow5_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow5_col2 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow5_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow5_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_46676efa_dc0c_11eb_8707_4ccc6adc65ce" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Vader_Compound</th>        <th class="col_heading level0 col1" >Vader_Average</th>        <th class="col_heading level0 col2" >WNSentiment</th>        <th class="col_heading level0 col3" >HVSentiment</th>        <th class="col_heading level0 col4" >LMSentiment</th>        <th class="col_heading level0 col5" >LogReturn</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_46676efa_dc0c_11eb_8707_4ccc6adc65celevel0_row0" class="row_heading level0 row0" >Vader_Compound</th>
#                         <td id="T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow0_col1" class="data row0 col1" >0.932693</td>
#                         <td id="T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow0_col2" class="data row0 col2" >0.080362</td>
#                         <td id="T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow0_col3" class="data row0 col3" >0.666828</td>
#                         <td id="T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow0_col4" class="data row0 col4" >0.418433</td>
#                         <td id="T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow0_col5" class="data row0 col5" >0.038313</td>
#             </tr>
#             <tr>
#                         <th id="T_46676efa_dc0c_11eb_8707_4ccc6adc65celevel0_row1" class="row_heading level0 row1" >Vader_Average</th>
#                         <td id="T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow1_col0" class="data row1 col0" >0.932693</td>
#                         <td id="T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow1_col2" class="data row1 col2" >0.037370</td>
#                         <td id="T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow1_col3" class="data row1 col3" >0.583740</td>
#                         <td id="T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow1_col4" class="data row1 col4" >0.350280</td>
#                         <td id="T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow1_col5" class="data row1 col5" >0.019549</td>
#             </tr>
#             <tr>
#                         <th id="T_46676efa_dc0c_11eb_8707_4ccc6adc65celevel0_row2" class="row_heading level0 row2" >WNSentiment</th>
#                         <td id="T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow2_col0" class="data row2 col0" >0.080362</td>
#                         <td id="T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow2_col1" class="data row2 col1" >0.037370</td>
#                         <td id="T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow2_col3" class="data row2 col3" >0.021909</td>
#                         <td id="T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow2_col4" class="data row2 col4" >0.488264</td>
#                         <td id="T_46676efa_dc0c_11eb_8707_4ccc6adc65cerow2_col5" class="data row2 col5" >0.113871</td>
#             </tr>
#             <tr>

# %%
pvals = [] 
for col in ["Vader_Compound","Vader_Average","WNSentiment","HVSentiment","LMSentiment"]:
    pvals.append(scipy.stats.linregress(Granger_data_daily['LogReturn'][1:], Granger_data_daily[col][1:].dropna())[3])
corr_signif = pd.DataFrame(pvals,columns = ['p-value']
                           ,index = ["Vader_Compound","Vader_Average","WNSentiment","HVSentiment","LMSentiment"])
corr_signif
# Out:
#                  p-value
# Vader_Compound  0.510868
# Vader_Average   0.744938
# WNSentiment     0.048039
# HVSentiment     0.998316
# LMSentiment     0.368807

# %%
pvals_mnt = [] 
for col in ['Vader_Compound','Flair_Score','SentimentScoreAdj','Vader_Average']:
    pvals_mnt.append(scipy.stats.linregress(Granger_data_monthly['LogReturn'][1:], Granger_data_monthly[col][1:].dropna())[3])
corr_signif_mnt = pd.DataFrame(pvals_mnt,columns = ['p-value']
                           ,index = ['Vader_Compound','Flair_Score','SentimentScoreAdj','Vader_Average'])
corr_signif_mnt
# Out:
#                     p-value
# Vader_Compound     0.084306
# Flair_Score        0.977764
# SentimentScoreAdj  0.311650
# Vader_Average      0.047369
