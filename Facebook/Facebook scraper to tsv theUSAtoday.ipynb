# %%
from facebook_scraper import get_posts
import csv

# %%
incremental_index = 1
with open('facebook_data_usatoday.tsv', 'w', encoding="utf-8") as tsvfile:
    tsv_writer = csv.writer(tsvfile, delimiter='\t')
    tsv_writer.writerow(['ID', 'PostID','PostDate','Text','Likes','Shares','Comments'])
    for post in get_posts('usatoday', pages=60000,timeout = 60, options={'comments': False},
                          cookies = "facebook_cookies.txt"):
        if post['text']!=None:
            row = [incremental_index, post['post_id'], post['time']
                   , post['text'].replace('\t',' ').replace('\n',' ').replace('USATODAY.COM','')
                   ,post['likes'],post['shares'],post['comments'], None]
            tsv_writer.writerow(row)
            incremental_index +=1
# Out:
# C:\Users\Windows\anaconda3\lib\site-packages\facebook_scraper\page_iterators.py:40: UserWarning: 500 Server Error: Internal Server Error for url: https://m.facebook.com/page_content_list_view/more/?page_id=13652355666&start_cursor=%7B%22timeline_cursor%22%3A%22AQHRYy1pkIZrKFST2Lx_FPaREeuBMT1tN_Qp0nTK4yQTKJkVZS0gmbTr6zWvzgRVJCnCQeDTpuQpEP5ee8ssOt4-O6ijPRt9HoVadwQHUG9AJRNfAqXQWiw2yjHPXOJBSczv%22%2C%22timeline_section_cursor%22%3Anull%2C%22has_next_page%22%3Atrue%7D&num_to_fetch=4&surface_type=posts_tab
#   warnings.warn(e)

# %%
tsvfile.close()

# %% [markdown]
# ## Comments

# %%
import pandas as pd
fpath = 'facebook_data_usatoday.tsv'
post_data = pd.read_csv(fpath, sep='\t',index_col=None)

# %%
post_data.columns = ['PostID','PostDate','Text','Likes','Share','Comments','Nan']

# %%
pos_ids = list(post_data["PostID"])
count_ids = 3486
incremental_index = 24032

# %%
with open('facebook_data_usatoday_comments_v3.tsv', 'a', encoding="utf-8") as tsvfile:
    tsv_writer = csv.writer(tsvfile, delimiter='\t')
    #tsv_writer.writerow(['ID', 'PostID','PostDate','CommentID','CommentDate','CommenterURL','CommentText'])
    for post_id in pos_ids:
        try:
            for post in get_posts(post_urls=[post_id],timeout = 60, options={'comments': True},
                          cookies = "facebook_cookies.txt"):
                if post['comments']>0:
                    if post['comments_full'] == None:
                        print("You are temporarely blocked! Come and run the code later")
                        print("Last post number is:" + str(count_ids) )
                        #pos_ids = pos_ids[count_ids:]

                    else:
                        comment_counter = 0
                        row = [incremental_index, post['post_id'],post['time'],None, None,None,None]
                        for comment in post['comments_full']:
                            row[3] = comment['comment_id']
                            row[4] = comment['comment_time']
                            row[5] = comment['commenter_url'].replace('https://facebook.com/',' ')
                            row[6] = comment['comment_text'].replace('\t',' ').replace('\n',' ')
                            tsv_writer.writerow(row)
                            incremental_index +=1
                            row[0] = incremental_index
                            comment_counter+=1

        except:
            None
        count_ids+=1

# %%
pos_ids = list(post_data["PostID"])
for i in range(len(pos_ids)):
    if pos_ids[i] == 913837065351286:
        print(i)
# Out:
# 9373

# %%
pos_ids = list(post_data["PostID"])
pos_ids = pos_ids[9373+1:]
count_ids = 9373+1

# %%
exclusions = []
for post_id in pos_ids:
    try:
        x=list(get_posts(post_urls=[post_id],timeout = 60, options={'comments': True},
                          cookies = "facebook_cookies.txt"))
        x[0]['post_id']
    except:
        exclusions.append(post_id)
exclusions
# Out:
# [1611029778965341,
#  1596278080440511,
#  1596277890440530,
#  1571991806202472,
#  1543812259020427,
#  1532606593474327,
#  1521747107893609,
#  1520012091400444,
#  1518999944834992,
#  1502554603146193,
#  429799003755097,
#  429344230467241,
#  429192870482377,
#  428893887178942,
#  427670483967949,
#  427522807316050,
#  427072374027760,
#  426694597398871,
#  426390764095921,
#  426209657447365,
#  424023740999290,
#  423684941033170,
#  423293947738936,
#  423127281088936,
#  422799194455078,
#  421358447932486,
#  421250124609985,
#  420862487982082,
#  420638711337793,
#  420235768044754,
#  419883651413299,
#  419577494777248,
#  418548024880195,
#  418230838245247,
#  418122054922792,
#  414491651952499,
#  412455775489420,
#  412195455515452,
#  411985985536399,
#  411658078902523,
#  411211918947139,
#  410966402305024,
#  409677605767237,
#  409555429112788,
#  409334182468246,
#  409214469146884,
#  408831915851806,
#  408557165879281,
#  408375062564158,
#  408072625927735,
#  407283709339960,
#  406998239368507,
#  406628286072169,
#  406517826083215,
#  406441189424212,
#  406232646111733,
#  406087489459582,
#  405724359495895,
#  405523752849289,
#  404154022986262,
#  403871416347856,
#  403614396373558,
#  403451106389887,
#  403184693083195,
#  402760549792276,
#  402651269803204,
#  401299859938345,
#  400864773315187,
#  400137293387935,
#  400133143388350,
#  399114636823534,
#  398814106853587,
#  398655760202755,
#  398476473554017,
#  398412673560397,
#  398316476903350,
#  398300576904940,
#  398112606923737,
#  398055743596090,
#  398035836931414,
#  397829020285429,
#  397742730294058,
#  397604570307874,
#  396734587061539,
#  396424473759217,
#  396254410442890,
#  395976040470727,
#  395306363871028,
#  395287340539597,
#  394202927314705,
#  394141540654177,
#  393952477339750,
#  393791097355888,
#  393611534040511,
#  393545424047122,
#  393160487418949,
#  393104177424580,
#  392719714129693,
#  392690407465957,
#  391366484265016,
#  391087540959577,
#  391049280963403,
#  390672734334391,
#  390519521016379,
#  390301827704815,
#  389097604491904,
#  388418017893196,
#  388044421263889,
#  387691014632563,
#  386693418065656,
#  386639058071092,
#  386365868098411,
#  386264044775260,
#  386061968128801,
#  385935798141418,
#  385725121495819,
#  385614054840259,
#  385377124863952,
#  384383281630003,
#  384082231660108,
#  383884221679909,
#  383703018364696,
#  383636675037997,
#  383551675046497,
#  383212928413705,
#  382979581770373,
#  382906655110999,
#  381812618553736,
#  381481328586865,
#  381229595278705,
#  380867948648203,
#  379568305444834,
#  378810698853928,
#  376868632381468,
#  376863029048695,
#  376854962382835,
#  376846582383673,
#  376840719050926,
#  376831429051855,
#  376813252387006,
#  376807789054219,
#  376802099054788,
#  376786855722979,
#  376777732390558,
#  376765412391790,
#  376764649058533,
#  376751139059884,
#  376750112393320,
#  361881817213483,
#  369923386409326,
#  366500986751566,
#  365471250187873,
#  363251263743205,
#  352449864823345,
#  338182066250125,
#  323573911044274,
#  322659174469081,
#  299262533475412,
#  298677776867221,
#  296641457070853,
#  295187783882887,
#  280183152050017,
#  265005446901121,
#  252332388168427,
#  244734132261586,
#  240907095977623,
#  225713874163612,
#  210336545701345,
#  209870335747966,
#  203435099724823,
#  195703657164634,
#  193325787402421,
#  192852927449707,
#  192384494163217,
#  189670487767951,
#  180777235323943,
#  173958699339130,
#  161036290631371,
#  161034977298169,
#  154983524569981]

# %%
for excl in exclusions:
    pos_ids.remove(excl)
    
len(pos_ids)
# Out:
# 11777

# %%
pos_ids = list(post_data["PostID"])
pos_ids[1257]
# Out:
# 3171466192921684

# %%
list(get_posts(post_urls=[1876283269106656],timeout = 60, options={'comments': True},
                          cookies = "facebook_cookies.txt"))[0]['post_id']
# Out:
# '1876283269106656'
